# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing Covid-19 Data
#
# _Author: B Rhodes (DC)_
#
# ---

# %% [markdown]
# For Project 2, you'll be using Python to perform fundamental exploratory data analysis (EDA) tasks. In the other notebook in this project, we can use Pandas, but this notebook you should only use Python. The purpose here is to flex your Python muscles while thinking about data.
#
# Below you'll import a data file with information on Covid-19 in a number of patients from the Cleveland Clinic. The original data along with a data dictionary can be found at the [John Hopkins University: CSSEGISandData/COVID-19](https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data).
#
#
# For these exercises, you will conduct basic exploratory data analysis using Python (Pandas is not allowed for this notebook). The goal is to understand the some fundamentals of the COVID-19 data: These exercises will allow you to practice business analysis skills while also becoming more comfortable with Python.

# %% [markdown]
# ---
#
# ## Part 1: Load the data & initial exploration

# %% [markdown]
# ### Problem 1: Load the file and store it in an object called `covid_csv`.
#
# Hint: This is a csv (comma-separated value) file, so we'll use `csv.reader()`
#
# See: [Python Docs - csv](https://docs.python.org/2/library/csv.html).

# %%
import csv

# import namedtuple as an option to store the data rows
from collections import namedtuple, defaultdict

DATA_FILE = './data/covid.csv'

# %% [markdown]
# #### Load the data

# %%
with open(DATA_FILE, 'r') as f:
    covid_csv = [row for row in csv.reader(f)]

# %%
covid_csv[0:3]
# Out:
# [['Combined_Key',
#   'Country_Region',
#   'Confirmed',
#   'Deaths',
#   'Recovered',
#   'Active',
#   'Incidence_Rate',
#   'Case_Fatality_Ratio'],
#  ['Afghanistan',
#   'Afghanistan',
#   '37345',
#   '1354',
#   '26694',
#   '9297.0',
#   '95.93267794278722',
#   '3.6256526978176464'],
#  ['Albania',
#   'Albania',
#   '6817',
#   '208',
#   '3552',
#   '3057.0',
#   '236.882340676906',
#   '3.0511955405603635']]

# %% [markdown]
# ### Problem 2: Separate ```covid_csv``` into a `header` and `data`.
#
# Complete the following tasks:
#
# 1. Split the covid_csv object into a ```header``` and ```data```.
#     1. display the ```header```
#     2. display the first 3 rows of ```data```.
# 2. What are dimensions of your data? Print the result (neatly formatted and each dimension identified.)

# %% [markdown]
# **Define the header and display the contents.**

# %%
header = covid_csv[0]
header
# Out:
# ['Combined_Key',
#  'Country_Region',
#  'Confirmed',
#  'Deaths',
#  'Recovered',
#  'Active',
#  'Incidence_Rate',
#  'Case_Fatality_Ratio']

# %% [markdown]
# **Define the data and display the first 3 rows.**

# %%
# Assign the data only
# display the first 3 rows
data = covid_csv[1:]
data[0:3]
# Out:
# [['Afghanistan',
#   'Afghanistan',
#   '37345',
#   '1354',
#   '26694',
#   '9297.0',
#   '95.93267794278722',
#   '3.6256526978176464'],
#  ['Albania',
#   'Albania',
#   '6817',
#   '208',
#   '3552',
#   '3057.0',
#   '236.882340676906',
#   '3.0511955405603635'],
#  ['Algeria',
#   'Algeria',
#   '36699',
#   '1333',
#   '25627',
#   '9739.0',
#   '83.69014164611774',
#   '3.6322515599880094']]

# %% [markdown]
# **Bonus: Use ```namedtuple``` to assign the data.**

# %%
# Alternative : use namedtuple
# define the namedtuple called CovidData and assign column names

import collections as col
covid_data = col.namedtuple('CovidData',header)

# %%
data_named = []

# %%
#List of tuples
for row in covid_csv[1:]:
     data_named.append(covid_data._make(row))

# %%
type(data_named )
# Out:
# list

# %%
# Check the header of the namedtuple
covid_data._fields
# Out:
# ('Combined_Key',
#  'Country_Region',
#  'Confirmed',
#  'Deaths',
#  'Recovered',
#  'Active',
#  'Incidence_Rate',
#  'Case_Fatality_Ratio')

# %% [markdown]
# **How many rows and how many columns?**

# %%
# print the rows and columns in data - label the output
#get row count 
print(f"How many rows in data list? {len(data)}")
 
#get column count for 1 row
print(f"How many columns in header? {len(header)}")
# Out:
# How many rows in data list? 3941
# How many columns in header? 8

# %%
# print the rows and columns in the namedtuple data_named - label the output
len_rows_data_named = len(data_named[:])
print(f"Rows in namedtuple: {len_rows_data_named}")
len_col_data_named = len(covid_data._fields) 
print(f"Columns in namedtuple: {len_col_data_named}")
# Out:
# Rows in namedtuple: 3941
# Columns in namedtuple: 8

# %% [markdown]
# ### Problem 3: Check the data type of each column and convert all numeric values to floats.
#
# Complete the following tasks:
#
# 1. Check data types (you only have to do this for one row).
# 2. Convert all numeric values to floats.
#
#
# Note: only print the data type once per column (i.e. only do this for 1 row of data.
#
# **Format your output neatly and annotate properly.** Unannotated lists of data types will not receive credit. This means you should match each column name to a data type and display the combination.

# %%
# 1 Check data types (you only have to do this for one row).
for i,col in enumerate(data[0]):
    print( header[i],"",type(col))
# Out:
# Combined_Key  <class 'str'>
# Country_Region  <class 'str'>
# Confirmed  <class 'str'>
# Deaths  <class 'str'>
# Recovered  <class 'str'>
# Active  <class 'str'>
# Incidence_Rate  <class 'str'>
# Case_Fatality_Ratio  <class 'str'>

# %%
# check data types for each column in tuple
for tup in data_named[0:1]:
    for i,item in enumerate(tup):
        print(covid_data._fields[i]," ", type(item))
# Out:
# Combined_Key   <class 'str'>
# Country_Region   <class 'str'>
# Confirmed   <class 'str'>
# Deaths   <class 'str'>
# Recovered   <class 'str'>
# Active   <class 'str'>
# Incidence_Rate   <class 'str'>
# Case_Fatality_Ratio   <class 'str'>

# %%
for x in data_named[0:1] :
    for i in range(len_col_data_named):
        print( covid_data._fields[i],type(x[i]))
# Out:
# Combined_Key <class 'str'>
# Country_Region <class 'str'>
# Confirmed <class 'str'>
# Deaths <class 'str'>
# Recovered <class 'str'>
# Active <class 'str'>
# Incidence_Rate <class 'str'>
# Case_Fatality_Ratio <class 'str'>

# %%
for x in data_named[0:1] :
    for i in range(len_col_data_named):
        print(x[i])
# Out:
# Afghanistan
# Afghanistan
# 37345
# 1354
# 26694
# 9297.0
# 95.93267794278722
# 3.6256526978176464

# %%
data_named[0:1]
# Out:
# [CovidData(Combined_Key='Afghanistan', Country_Region='Afghanistan', Confirmed='37345', Deaths='1354', Recovered='26694', Active='9297.0', Incidence_Rate='95.93267794278722', Case_Fatality_Ratio='3.6256526978176464')]

# %%
len_col_data_named
# Out:
# 8

# %%
test = []

for x in data_named[0:1] :
    col_type = []
    col_type.append(type(x.Combined_Key))    
    col_type.append(type (x.Country_Region))   
    col_type.append(type  (x.Confirmed ))
    col_type.append(type  (x.Deaths))  
    col_type.append(type (x.Recovered )) 
    col_type.append(type  (x.Active )) 
    col_type.append(type (x.Incidence_Rate))   
    col_type.append(type (x.Case_Fatality_Ratio))
    test.append(tuple(col_type))
test
# Out:
# [(str, str, str, str, str, str, str, str)]

# %%
for i , row in enumerate (data_named):
    col_values = []
    print(row)
# Out:
# CovidData(Combined_Key='Afghanistan', Country_Region='Afghanistan', Confirmed='37345', Deaths='1354', Recovered='26694', Active='9297.0', Incidence_Rate='95.93267794278722', Case_Fatality_Ratio='3.6256526978176464')
# CovidData(Combined_Key='Albania', Country_Region='Albania', Confirmed='6817', Deaths='208', Recovered='3552', Active='3057.0', Incidence_Rate='236.882340676906', Case_Fatality_Ratio='3.0511955405603635')
# CovidData(Combined_Key='Algeria', Country_Region='Algeria', Confirmed='36699', Deaths='1333', Recovered='25627', Active='9739.0', Incidence_Rate='83.69014164611774', Case_Fatality_Ratio='3.6322515599880094')
# CovidData(Combined_Key='Andorra', Country_Region='Andorra', Confirmed='977', Deaths='53', Recovered='855', Active='69.0', Incidence_Rate='1264.4793891153822', Case_Fatality_Ratio='5.424769703172978')
# CovidData(Combined_Key='Angola', Country_Region='Angola', Confirmed='1762', Deaths='80', Recovered='577', Active='1105.0', Incidence_Rate='5.361119796138704', Case_Fatality_Ratio='4.540295119182747')
# CovidData(Combined_Key='Antigua and Barbuda', Country_Region='Antigua and Barbuda', Confirmed='92', Deaths='3', Recovered='76', Active='13.0', Incidence_Rate='93.94657299240258', Case_Fatality_Ratio='3.260869565217391')
# CovidData(Combined_Key='Argentina', Country_Region='Argentina', Confirmed='268574', Deaths='5213', Recovered='187283', Active='76078.0', Incidence_Rate='594.2457853971622', Case_Fatality_Ratio='1.9409920543313948')
# CovidData(Combined_Key='Armenia', Country_Region='Armenia', Confirmed='40794', Deaths='806', Recovered='33492', Active='6496.0', Incidence_Rate='1376.6715689682287', Case_Fatality_Ratio='1.975780752071383')
# CovidData(Combined_Key='Australian Capital Territory, Australia', Country_Region='Australia', Confirmed='113', Deaths='3', Recovered='110', Active='0.0', Incidence_Rate='26.395701938799345', Case_Fatality_Ratio='2.6548672566371683')
# CovidData(Combined_Key='New South Wales, Australia', Country_Region='Australia', Confirmed='3927', Deaths='51', Recovered='2994', Active='882.0', Incidence_Rate='48.3739837398374', Case_Fatality_Ratio='1.2987012987012987')
# CovidData(Combined_Key='Northern Territory, Australia', Country_Region='Australia', Confirmed='33', Deaths='0', Recovered='31', Active='2.0', Incidence_Rate='13.436482084690551', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Queensland, Australia', Country_Region='Australia', Confirmed='1089', Deaths='6', Recovered='1076', Active='7.0', Incidence_Rate='21.28824161861011', Case_Fatality_Ratio='0.5509641873278237')
# CovidData(Combined_Key='South Australia, Australia', Country_Region='Australia', Confirmed='459', Deaths='4', Recovered='449', Active='6.0', Incidence_Rate='26.131511528608023', Case_Fatality_Ratio='0.8714596949891068')
# CovidData(Combined_Key='Tasmania, Australia', Country_Region='Australia', Confirmed='230', Deaths='13', Recovered='216', Active='1.0', Incidence_Rate='42.95051353874883', Case_Fatality_Ratio='5.652173913043479')
# CovidData(Combined_Key='Victoria, Australia', Country_Region='Australia', Confirmed='15863', Deaths='275', Recovered='7271', Active='8317.0', Incidence_Rate='239.26454395993903', Case_Fatality_Ratio='1.73359389774948')
# CovidData(Combined_Key='Western Australia, Australia', Country_Region='Australia', Confirmed='644', Deaths='9', Recovered='632', Active='3.0', Incidence_Rate='24.481106971793512', Case_Fatality_Ratio='1.3975155279503106')
# CovidData(Combined_Key='Austria', Country_Region='Austria', Confirmed='22439', Deaths='724', Recovered='20268', Active='1447.0', Incidence_Rate='249.1450524071772', Case_Fatality_Ratio='3.2265252462230936')
# CovidData(Combined_Key='Azerbaijan', Country_Region='Azerbaijan', Confirmed='33824', Deaths='497', Recovered='31058', Active='2269.0', Incidence_Rate='333.5971615047576', Case_Fatality_Ratio='1.4693708609271523')
# CovidData(Combined_Key='Bahamas', Country_Region='Bahamas', Confirmed='1036', Deaths='15', Recovered='122', Active='899.0', Incidence_Rate='263.44698510863367', Case_Fatality_Ratio='1.4478764478764483')
# CovidData(Combined_Key='Bahrain', Country_Region='Bahrain', Confirmed='45264', Deaths='166', Recovered='41836', Active='3262.0', Incidence_Rate='2660.111202333357', Case_Fatality_Ratio='0.3667373630258042')
# CovidData(Combined_Key='Bangladesh', Country_Region='Bangladesh', Confirmed='266498', Deaths='3513', Recovered='153089', Active='109896.0', Incidence_Rate='161.81856726004008', Case_Fatality_Ratio='1.318208767045156')
# CovidData(Combined_Key='Barbados', Country_Region='Barbados', Confirmed='144', Deaths='7', Recovered='115', Active='22.0', Incidence_Rate='50.10944040978386', Case_Fatality_Ratio='4.861111111111111')
# CovidData(Combined_Key='Belarus', Country_Region='Belarus', Confirmed='69102', Deaths='595', Recovered='65893', Active='2614.0', Incidence_Rate='731.2906398248085', Case_Fatality_Ratio='0.8610459899858179')
# CovidData(Combined_Key='Belgium', Country_Region='Belgium', Confirmed='75647', Deaths='9900', Recovered='17883', Active='47864.0', Incidence_Rate='652.7136015550473', Case_Fatality_Ratio='13.087101933982842')
# CovidData(Combined_Key='Belize', Country_Region='Belize', Confirmed='210', Deaths='2', Recovered='32', Active='176.0', Incidence_Rate='52.8141119307079', Case_Fatality_Ratio='0.9523809523809524')
# CovidData(Combined_Key='Benin', Country_Region='Benin', Confirmed='2014', Deaths='38', Recovered='1681', Active='295.0', Incidence_Rate='16.612778245476154', Case_Fatality_Ratio='1.8867924528301887')
# CovidData(Combined_Key='Bhutan', Country_Region='Bhutan', Confirmed='113', Deaths='0', Recovered='97', Active='16.0', Incidence_Rate='14.644665972017028', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Bolivia', Country_Region='Bolivia', Confirmed='95071', Deaths='3827', Recovered='32830', Active='58414.0', Incidence_Rate='814.4501311527624', Case_Fatality_Ratio='4.025412586382808')
# CovidData(Combined_Key='Bosnia and Herzegovina', Country_Region='Bosnia and Herzegovina', Confirmed='14961', Deaths='453', Recovered='8827', Active='5681.0', Incidence_Rate='456.01474023984895', Case_Fatality_Ratio='3.0278724684178866')
# CovidData(Combined_Key='Botswana', Country_Region='Botswana', Confirmed='1066', Deaths='2', Recovered='80', Active='984.0', Incidence_Rate='45.33035666826131', Case_Fatality_Ratio='0.18761726078799248')
# CovidData(Combined_Key='Acre, Brazil', Country_Region='Brazil', Confirmed='21993', Deaths='569', Recovered='15307', Active='6117.0', Incidence_Rate='2493.7211926048967', Case_Fatality_Ratio='2.5871868321738734')
# CovidData(Combined_Key='Alagoas, Brazil', Country_Region='Brazil', Confirmed='69751', Deaths='1711', Recovered='63287', Active='4753.0', Incidence_Rate='2090.0071523663787', Case_Fatality_Ratio='2.45301142635948')
# CovidData(Combined_Key='Amapa, Brazil', Country_Region='Brazil', Confirmed='38801', Deaths='606', Recovered='26773', Active='11422.0', Incidence_Rate='4587.865408741077', Case_Fatality_Ratio='1.5618154171284244')
# CovidData(Combined_Key='Amazonas, Brazil', Country_Region='Brazil', Confirmed='108920', Deaths='3417', Recovered='92335', Active='13168.0', Incidence_Rate='2627.9997789893687', Case_Fatality_Ratio='3.1371648916636063')
# CovidData(Combined_Key='Bahia, Brazil', Country_Region='Brazil', Confirmed='203020', Deaths='4135', Recovered='184444', Active='14441.0', Incidence_Rate='1365.0179949471071', Case_Fatality_Ratio='2.036745148261255')
# CovidData(Combined_Key='Ceara, Brazil', Country_Region='Brazil', Confirmed='192422', Deaths='8052', Recovered='164954', Active='19416.0', Incidence_Rate='2107.0998298525265', Case_Fatality_Ratio='4.184552701874006')
# CovidData(Combined_Key='Distrito Federal, Brazil', Country_Region='Brazil', Confirmed='129184', Deaths='1870', Recovered='110632', Active='16682.0', Incidence_Rate='4284.328955170818', Case_Fatality_Ratio='1.4475476839237058')
# CovidData(Combined_Key='Espirito Santo, Brazil', Country_Region='Brazil', Confirmed='95753', Deaths='2805', Recovered='81923', Active='11025.0', Incidence_Rate='2382.7155885683005', Case_Fatality_Ratio='2.9294121333013066')
# CovidData(Combined_Key='Goias, Brazil', Country_Region='Brazil', Confirmed='93274', Deaths='2135', Recovered='85214', Active='5925.0', Incidence_Rate='1329.0010734710734', Case_Fatality_Ratio='2.2889551214700776')
# CovidData(Combined_Key='Maranhao, Brazil', Country_Region='Brazil', Confirmed='133265', Deaths='3215', Recovered='123772', Active='6278.0', Incidence_Rate='1883.5560531949645', Case_Fatality_Ratio='2.4124863992796306')
# CovidData(Combined_Key='Mato Grosso, Brazil', Country_Region='Brazil', Confirmed='68924', Deaths='2221', Recovered='46355', Active='20348.0', Incidence_Rate='1978.0362328115696', Case_Fatality_Ratio='3.2223898787069816')
# CovidData(Combined_Key='Mato Grosso do Sul, Brazil', Country_Region='Brazil', Confirmed='33509', Deaths='558', Recovered='27329', Active='5622.0', Incidence_Rate='1205.7995254384152', Case_Fatality_Ratio='1.6652242681070757')
# CovidData(Combined_Key='Minas Gerais, Brazil', Country_Region='Brazil', Confirmed='160485', Deaths='3783', Recovered='128957', Active='27745.0', Incidence_Rate='758.1207637224063', Case_Fatality_Ratio='2.35722964763062')
# CovidData(Combined_Key='Para, Brazil', Country_Region='Brazil', Confirmed='171878', Deaths='5909', Recovered='157802', Active='8167.0', Incidence_Rate='1997.9158106049554', Case_Fatality_Ratio='3.43790362931847')
# CovidData(Combined_Key='Paraiba, Brazil', Country_Region='Brazil', Confirmed='92897', Deaths='2071', Recovered='47111', Active='43715.0', Incidence_Rate='2311.9478304194963', Case_Fatality_Ratio='2.2293507863547797')
# CovidData(Combined_Key='Parana, Brazil', Country_Region='Brazil', Confirmed='97785', Deaths='2516', Recovered='58064', Active='37205.0', Incidence_Rate='855.2157402725933', Case_Fatality_Ratio='2.5729917676535257')
# CovidData(Combined_Key='Pernambuco, Brazil', Country_Region='Brazil', Confirmed='107375', Deaths='7049', Recovered='88252', Active='12074.0', Incidence_Rate='1123.5136790340891', Case_Fatality_Ratio='6.564842840512223')
# CovidData(Combined_Key='Piaui, Brazil', Country_Region='Brazil', Confirmed='62465', Deaths='1548', Recovered='61433', Active='-516.0', Incidence_Rate='1908.361381596816', Case_Fatality_Ratio='2.4781877851596894')
# CovidData(Combined_Key='Rio Grande do Norte, Brazil', Country_Region='Brazil', Confirmed='56572', Deaths='2019', Recovered='28243', Active='26310.0', Incidence_Rate='1613.184242396245', Case_Fatality_Ratio='3.5689033444106624')
# CovidData(Combined_Key='Rio Grande do Sul, Brazil', Country_Region='Brazil', Confirmed='90049', Deaths='2540', Recovered='79763', Active='7746.0', Incidence_Rate='791.4837686015035', Case_Fatality_Ratio='2.820686515119547')
# CovidData(Combined_Key='Rio de Janeiro, Brazil', Country_Region='Brazil', Confirmed='185610', Deaths='14295', Recovered='165894', Active='5421.0', Incidence_Rate='1075.0687100443943', Case_Fatality_Ratio='7.701632455147891')
# CovidData(Combined_Key='Rondonia, Brazil', Country_Region='Brazil', Confirmed='46061', Deaths='981', Recovered='38312', Active='6768.0', Incidence_Rate='2591.737118260209', Case_Fatality_Ratio='2.129784416317492')
# CovidData(Combined_Key='Roraima, Brazil', Country_Region='Brazil', Confirmed='37579', Deaths='555', Recovered='9125', Active='27899.0', Incidence_Rate='6203.601750525372', Case_Fatality_Ratio='1.4768886878309695')
# CovidData(Combined_Key='Santa Catarina, Brazil', Country_Region='Brazil', Confirmed='112401', Deaths='1637', Recovered='99781', Active='10983.0', Incidence_Rate='1568.797290303635', Case_Fatality_Ratio='1.4563927367194245')
# CovidData(Combined_Key='Sao Paulo, Brazil', Country_Region='Brazil', Confirmed='655181', Deaths='25869', Recovered='453612', Active='175700.0', Incidence_Rate='1426.8174412758415', Case_Fatality_Ratio='3.948374571301671')
# CovidData(Combined_Key='Sergipe, Brazil', Country_Region='Brazil', Confirmed='65865', Deaths='1653', Recovered='47709', Active='16503.0', Incidence_Rate='2865.3201641278365', Case_Fatality_Ratio='2.509678888635846')
# CovidData(Combined_Key='Tocantins, Brazil', Country_Region='Brazil', Confirmed='33766', Deaths='482', Recovered='19845', Active='13439.0', Incidence_Rate='2146.7817347440914', Case_Fatality_Ratio='1.4274714209559909')
# CovidData(Combined_Key='Brunei', Country_Region='Brunei', Confirmed='142', Deaths='3', Recovered='138', Active='1.0', Incidence_Rate='32.45840409798781', Case_Fatality_Ratio='2.112676056338028')
# CovidData(Combined_Key='Bulgaria', Country_Region='Bulgaria', Confirmed='13893', Deaths='482', Recovered='8479', Active='4932.0', Incidence_Rate='199.9440162511181', Case_Fatality_Ratio='3.4693730655725905')
# CovidData(Combined_Key='Burkina Faso', Country_Region='Burkina Faso', Confirmed='1213', Deaths='54', Recovered='995', Active='164.0', Incidence_Rate='5.802917609381647', Case_Fatality_Ratio='4.451772464962902')
# CovidData(Combined_Key='Burma', Country_Region='Burma', Confirmed='361', Deaths='6', Recovered='318', Active='37.0', Incidence_Rate='0.6634834897555393', Case_Fatality_Ratio='1.6620498614958448')
# CovidData(Combined_Key='Burundi', Country_Region='Burundi', Confirmed='409', Deaths='1', Recovered='315', Active='93.0', Incidence_Rate='3.439639498868914', Case_Fatality_Ratio='0.2444987775061125')
# CovidData(Combined_Key='Cabo Verde', Country_Region='Cabo Verde', Confirmed='3000', Deaths='33', Recovered='2172', Active='795.0', Incidence_Rate='539.5799909350561', Case_Fatality_Ratio='1.1')
# CovidData(Combined_Key='Cambodia', Country_Region='Cambodia', Confirmed='272', Deaths='0', Recovered='223', Active='49.0', Incidence_Rate='1.6268943824353783', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Cameroon', Country_Region='Cameroon', Confirmed='18263', Deaths='401', Recovered='15320', Active='2542.0', Incidence_Rate='68.79791141851703', Case_Fatality_Ratio='2.195696216393802')
# CovidData(Combined_Key='Alberta, Canada', Country_Region='Canada', Confirmed='11893', Deaths='217', Recovered='10632', Active='1044.0', Incidence_Rate='269.49029105313986', Case_Fatality_Ratio='1.824602707474985')
# CovidData(Combined_Key='British Columbia, Canada', Country_Region='Canada', Confirmed='4111', Deaths='195', Recovered='3444', Active='472.0', Incidence_Rate='80.43566350226386', Case_Fatality_Ratio='4.7433714424714175')
# CovidData(Combined_Key='Grand Princess, Canada', Country_Region='Canada', Confirmed='13', Deaths='0', Recovered='13', Active='0.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Manitoba, Canada', Country_Region='Canada', Confirmed='578', Deaths='8', Recovered='368', Active='202.0', Incidence_Rate='41.95955476411543', Case_Fatality_Ratio='1.3840830449826989')
# CovidData(Combined_Key='New Brunswick, Canada', Country_Region='Canada', Confirmed='178', Deaths='2', Recovered='168', Active='8.0', Incidence_Rate='22.82071762182481', Case_Fatality_Ratio='1.1235955056179776')
# CovidData(Combined_Key='Newfoundland and Labrador, Canada', Country_Region='Canada', Confirmed='268', Deaths='3', Recovered='263', Active='2.0', Incidence_Rate='51.40352727935323', Case_Fatality_Ratio='1.1194029850746268')
# CovidData(Combined_Key='Northwest Territories,Canada', Country_Region='Canada', Confirmed='5', Deaths='0', Recovered='5', Active='0.0', Incidence_Rate='11.134865490824867', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Nova Scotia, Canada', Country_Region='Canada', Confirmed='1071', Deaths='64', Recovered='1007', Active='0.0', Incidence_Rate='109.57003735202672', Case_Fatality_Ratio='5.975723622782446')
# CovidData(Combined_Key='Ontario, Canada', Country_Region='Canada', Confirmed='42233', Deaths='2833', Recovered='38296', Active='1104.0', Incidence_Rate='287.068356635787', Case_Fatality_Ratio='6.708024530580353')
# CovidData(Combined_Key='Prince Edward Island, Canada', Country_Region='Canada', Confirmed='41', Deaths='0', Recovered='36', Active='5.0', Incidence_Rate='25.92344364496263', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Quebec, Canada', Country_Region='Canada', Confirmed='60813', Deaths='5709', Recovered='53270', Active='1834.0', Incidence_Rate='712.2900218490422', Case_Fatality_Ratio='9.387795372699916')
# CovidData(Combined_Key='Saskatchewan, Canada', Country_Region='Canada', Confirmed='1484', Deaths='20', Recovered='1314', Active='150.0', Incidence_Rate='125.5854023048814', Case_Fatality_Ratio='1.3477088948787062')
# CovidData(Combined_Key='Yukon, Canada', Country_Region='Canada', Confirmed='15', Deaths='0', Recovered='13', Active='2.0', Incidence_Rate='36.515896586980865', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Central African Republic', Country_Region='Central African Republic', Confirmed='4652', Deaths='61', Recovered='1728', Active='2863.0', Incidence_Rate='96.3194060827817', Case_Fatality_Ratio='1.3112639724849526')
# CovidData(Combined_Key='Chad', Country_Region='Chad', Confirmed='949', Deaths='76', Recovered='859', Active='14.0', Incidence_Rate='5.7774756254756605', Case_Fatality_Ratio='8.008429926238145')
# CovidData(Combined_Key='Antofagasta, Chile', Country_Region='Chile', Confirmed='16323', Deaths='388', Recovered='14811', Active='1124.0', Incidence_Rate='2686.7632099602656', Case_Fatality_Ratio='2.3770140292838327')
# CovidData(Combined_Key='Araucania, Chile', Country_Region='Chile', Confirmed='4490', Deaths='83', Recovered='4139', Active='268.0', Incidence_Rate='469.06471212589736', Case_Fatality_Ratio='1.8485523385300668')
# CovidData(Combined_Key='Arica y Parinacota, Chile', Country_Region='Chile', Confirmed='5451', Deaths='78', Recovered='4613', Active='760.0', Incidence_Rate='2411.2214024098944', Case_Fatality_Ratio='1.4309301045679692')
# CovidData(Combined_Key='Atacama, Chile', Country_Region='Chile', Confirmed='4108', Deaths='21', Recovered='3077', Active='1010.0', Incidence_Rate='1421.7287778946786', Case_Fatality_Ratio='0.5111976630963972')
# CovidData(Combined_Key='Aysen, Chile', Country_Region='Chile', Confirmed='95', Deaths='1', Recovered='82', Active='12.0', Incidence_Rate='92.09174276352779', Case_Fatality_Ratio='1.0526315789473684')
# CovidData(Combined_Key='Biobio, Chile', Country_Region='Chile', Confirmed='13260', Deaths='145', Recovered='11644', Active='1471.0', Incidence_Rate='851.7444381280893', Case_Fatality_Ratio='1.0935143288084463')
# CovidData(Combined_Key='Coquimbo, Chile', Country_Region='Chile', Confirmed='7631', Deaths='89', Recovered='6636', Active='906.0', Incidence_Rate='1007.2783815962808', Case_Fatality_Ratio='1.1662953741318307')
# CovidData(Combined_Key='Los Lagos, Chile', Country_Region='Chile', Confirmed='5149', Deaths='54', Recovered='4152', Active='943.0', Incidence_Rate='621.3286223856894', Case_Fatality_Ratio='1.0487473295785592')
# CovidData(Combined_Key='Los Rios, Chile', Country_Region='Chile', Confirmed='987', Deaths='15', Recovered='903', Active='69.0', Incidence_Rate='256.47222070642897', Case_Fatality_Ratio='1.5197568389057752')
# CovidData(Combined_Key='Magallanes, Chile', Country_Region='Chile', Confirmed='2128', Deaths='30', Recovered='1788', Active='310.0', Incidence_Rate='1277.8248155020324', Case_Fatality_Ratio='1.4097744360902256')
# CovidData(Combined_Key='Maule, Chile', Country_Region='Chile', Confirmed='10058', Deaths='203', Recovered='9050', Active='805.0', Incidence_Rate='962.5340925403128', Case_Fatality_Ratio='2.0182938954066416')
# CovidData(Combined_Key='Metropolitana, Chile', Country_Region='Chile', Confirmed='263567', Deaths='7992', Recovered='249956', Active='5619.0', Incidence_Rate='3705.5267061897353', Case_Fatality_Ratio='3.0322460702591747')
# CovidData(Combined_Key='Nuble, Chile', Country_Region='Chile', Confirmed='3879', Deaths='69', Recovered='3535', Active='275.0', Incidence_Rate='807.1009906181532', Case_Fatality_Ratio='1.7788089713843769')
# CovidData(Combined_Key='OHiggins, Chile', Country_Region='Chile', Confirmed='11843', Deaths='281', Recovered='10621', Active='941.0', Incidence_Rate='1294.946722723073', Case_Fatality_Ratio='2.372709617495567')
# CovidData(Combined_Key='Tarapaca, Chile', Country_Region='Chile', Confirmed='9617', Deaths='182', Recovered='8789', Active='646.0', Incidence_Rate='2909.3230234936077', Case_Fatality_Ratio='1.8924820630134136')
# CovidData(Combined_Key='Unknown, Chile', Country_Region='Chile', Confirmed='64', Deaths='1', Recovered='61', Active='2.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='1.5625')
# CovidData(Combined_Key='Valparaiso, Chile', Country_Region='Chile', Confirmed='19518', Deaths='573', Recovered='17562', Active='1383.0', Incidence_Rate='1074.8377390409835', Case_Fatality_Ratio='2.9357516138948663')
# CovidData(Combined_Key='Anhui, China', Country_Region='China', Confirmed='991', Deaths='6', Recovered='985', Active='0.0', Incidence_Rate='1.5670461733080334', Case_Fatality_Ratio='0.6054490413723511')
# CovidData(Combined_Key='Beijing, China', Country_Region='China', Confirmed='935', Deaths='9', Recovered='920', Active='6.0', Incidence_Rate='4.340761374187558', Case_Fatality_Ratio='0.9625668449197858')
# CovidData(Combined_Key='Chongqing, China', Country_Region='China', Confirmed='583', Deaths='6', Recovered='577', Active='0.0', Incidence_Rate='1.8794326241134751', Case_Fatality_Ratio='1.0291595197255574')
# CovidData(Combined_Key='Fujian, China', Country_Region='China', Confirmed='368', Deaths='1', Recovered='364', Active='3.0', Incidence_Rate='0.933773154021822', Case_Fatality_Ratio='0.2717391304347826')
# CovidData(Combined_Key='Gansu, China', Country_Region='China', Confirmed='169', Deaths='2', Recovered='165', Active='2.0', Incidence_Rate='0.6408797876374668', Case_Fatality_Ratio='1.183431952662722')
# CovidData(Combined_Key='Guangdong, China', Country_Region='China', Confirmed='1707', Deaths='8', Recovered='1678', Active='21.0', Incidence_Rate='1.5044949762030673', Case_Fatality_Ratio='0.4686584651435266')
# CovidData(Combined_Key='Guangxi, China', Country_Region='China', Confirmed='255', Deaths='2', Recovered='253', Active='0.0', Incidence_Rate='0.5176613885505481', Case_Fatality_Ratio='0.7843137254901961')
# CovidData(Combined_Key='Guizhou, China', Country_Region='China', Confirmed='147', Deaths='2', Recovered='145', Active='0.0', Incidence_Rate='0.4083333333333333', Case_Fatality_Ratio='1.3605442176870748')
# CovidData(Combined_Key='Hainan, China', Country_Region='China', Confirmed='171', Deaths='6', Recovered='165', Active='0.0', Incidence_Rate='1.8308351177730195', Case_Fatality_Ratio='3.5087719298245608')
# CovidData(Combined_Key='Hebei, China', Country_Region='China', Confirmed='351', Deaths='6', Recovered='343', Active='2.0', Incidence_Rate='0.4645314981471678', Case_Fatality_Ratio='1.7094017094017089')
# CovidData(Combined_Key='Heilongjiang, China', Country_Region='China', Confirmed='948', Deaths='13', Recovered='934', Active='1.0', Incidence_Rate='2.5125894513649616', Case_Fatality_Ratio='1.3713080168776368')
# CovidData(Combined_Key='Henan, China', Country_Region='China', Confirmed='1276', Deaths='22', Recovered='1254', Active='0.0', Incidence_Rate='1.3284747527329517', Case_Fatality_Ratio='1.7241379310344829')
# CovidData(Combined_Key='Hong Kong, China', Country_Region='China', Confirmed='4243', Deaths='63', Recovered='3189', Active='991.0', Incidence_Rate='56.596062311957816', Case_Fatality_Ratio='1.4847984916332784')
# CovidData(Combined_Key='Hubei, China', Country_Region='China', Confirmed='68139', Deaths='4512', Recovered='63623', Active='4.0', Incidence_Rate='115.1580192665202', Case_Fatality_Ratio='6.6217584643155885')
# CovidData(Combined_Key='Hunan, China', Country_Region='China', Confirmed='1019', Deaths='4', Recovered='1015', Active='0.0', Incidence_Rate='1.4770256558921582', Case_Fatality_Ratio='0.3925417075564279')
# CovidData(Combined_Key='Inner Mongolia, China', Country_Region='China', Confirmed='259', Deaths='1', Recovered='254', Active='4.0', Incidence_Rate='1.022099447513812', Case_Fatality_Ratio='0.3861003861003861')
# CovidData(Combined_Key='Jiangsu, China', Country_Region='China', Confirmed='659', Deaths='0', Recovered='656', Active='3.0', Incidence_Rate='0.8185318593963483', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Jiangxi, China', Country_Region='China', Confirmed='932', Deaths='1', Recovered='931', Active='0.0', Incidence_Rate='2.0051635111876074', Case_Fatality_Ratio='0.1072961373390558')
# CovidData(Combined_Key='Jilin, China', Country_Region='China', Confirmed='157', Deaths='2', Recovered='154', Active='1.0', Incidence_Rate='0.5806213017751479', Case_Fatality_Ratio='1.2738853503184713')
# CovidData(Combined_Key='Liaoning, China', Country_Region='China', Confirmed='261', Deaths='2', Recovered='202', Active='57.0', Incidence_Rate='0.5987611837577426', Case_Fatality_Ratio='0.7662835249042146')
# CovidData(Combined_Key='Macau, China', Country_Region='China', Confirmed='46', Deaths='0', Recovered='46', Active='0.0', Incidence_Rate='7.084094360136879', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Ningxia, China', Country_Region='China', Confirmed='75', Deaths='0', Recovered='75', Active='0.0', Incidence_Rate='1.0901162790697674', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Qinghai, China', Country_Region='China', Confirmed='18', Deaths='0', Recovered='18', Active='0.0', Incidence_Rate='0.29850746268656714', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Shaanxi, China', Country_Region='China', Confirmed='341', Deaths='3', Recovered='324', Active='14.0', Incidence_Rate='0.8825051759834368', Case_Fatality_Ratio='0.8797653958944281')
# CovidData(Combined_Key='Shandong, China', Country_Region='China', Confirmed='821', Deaths='7', Recovered='789', Active='25.0', Incidence_Rate='0.8171593510500647', Case_Fatality_Ratio='0.8526187576126675')
# CovidData(Combined_Key='Shanghai, China', Country_Region='China', Confirmed='800', Deaths='7', Recovered='737', Active='56.0', Incidence_Rate='3.3003300330033003', Case_Fatality_Ratio='0.875')
# CovidData(Combined_Key='Shanxi, China', Country_Region='China', Confirmed='201', Deaths='0', Recovered='201', Active='0.0', Incidence_Rate='0.5406132329209252', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Sichuan, China', Country_Region='China', Confirmed='618', Deaths='3', Recovered='602', Active='13.0', Incidence_Rate='0.7409183551132957', Case_Fatality_Ratio='0.4854368932038835')
# CovidData(Combined_Key='Tianjin, China', Country_Region='China', Confirmed='205', Deaths='3', Recovered='202', Active='0.0', Incidence_Rate='1.314102564102564', Case_Fatality_Ratio='1.4634146341463414')
# CovidData(Combined_Key='Tibet, China', Country_Region='China', Confirmed='1', Deaths='0', Recovered='1', Active='0.0', Incidence_Rate='0.02906976744186046', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Xinjiang, China', Country_Region='China', Confirmed='883', Deaths='3', Recovered='375', Active='505.0', Incidence_Rate='3.5504624045034183', Case_Fatality_Ratio='0.3397508493771235')
# CovidData(Combined_Key='Yunnan, China', Country_Region='China', Confirmed='191', Deaths='2', Recovered='188', Active='1.0', Incidence_Rate='0.39544513457556935', Case_Fatality_Ratio='1.0471204188481675')
# CovidData(Combined_Key='Zhejiang, China', Country_Region='China', Confirmed='1275', Deaths='1', Recovered='1268', Active='6.0', Incidence_Rate='2.22241589681018', Case_Fatality_Ratio='0.0784313725490196')
# CovidData(Combined_Key='Amazonas, Colombia', Country_Region='Colombia', Confirmed='2641', Deaths='105', Recovered='2388', Active='148.0', Incidence_Rate='3448.2758620689656', Case_Fatality_Ratio='3.975766755017039')
# CovidData(Combined_Key='Antioquia, Colombia', Country_Region='Colombia', Confirmed='55820', Deaths='989', Recovered='25896', Active='28935.0', Incidence_Rate='871.2207172603153', Case_Fatality_Ratio='1.7717663919742028')
# CovidData(Combined_Key='Arauca, Colombia', Country_Region='Colombia', Confirmed='511', Deaths='9', Recovered='197', Active='305.0', Incidence_Rate='194.9087247400581', Case_Fatality_Ratio='1.761252446183953')
# CovidData(Combined_Key='Atlantico, Colombia', Country_Region='Colombia', Confirmed='59383', Deaths='2726', Recovered='46990', Active='9667.0', Incidence_Rate='2342.0470065868217', Case_Fatality_Ratio='4.590539379957226')
# CovidData(Combined_Key='Bolivar, Colombia', Country_Region='Colombia', Confirmed='20925', Deaths='635', Recovered='16679', Active='3611.0', Incidence_Rate='1010.8158503654396', Case_Fatality_Ratio='3.034647550776583')
# CovidData(Combined_Key='Boyaca, Colombia', Country_Region='Colombia', Confirmed='1763', Deaths='43', Recovered='765', Active='955.0', Incidence_Rate='144.8196777330915', Case_Fatality_Ratio='2.4390243902439024')
# CovidData(Combined_Key='Caldas, Colombia', Country_Region='Colombia', Confirmed='1455', Deaths='22', Recovered='511', Active='922.0', Incidence_Rate='145.75434132561318', Case_Fatality_Ratio='1.5120274914089349')
# CovidData(Combined_Key='Capital District, Colombia', Country_Region='Colombia', Confirmed='146109', Deaths='3998', Recovered='75551', Active='66560.0', Incidence_Rate='1971.0988070797614', Case_Fatality_Ratio='2.736313300344264')
# CovidData(Combined_Key='Caqueta, Colombia', Country_Region='Colombia', Confirmed='2944', Deaths='82', Recovered='958', Active='1904.0', Incidence_Rate='733.2704009325287', Case_Fatality_Ratio='2.785326086956522')
# CovidData(Combined_Key='Casanare, Colombia', Country_Region='Colombia', Confirmed='535', Deaths='9', Recovered='207', Active='319.0', Incidence_Rate='127.22827844681619', Case_Fatality_Ratio='1.6822429906542056')
# CovidData(Combined_Key='Cauca, Colombia', Country_Region='Colombia', Confirmed='2810', Deaths='101', Recovered='1473', Active='1236.0', Incidence_Rate='191.8759320663604', Case_Fatality_Ratio='3.5943060498220643')
# CovidData(Combined_Key='Cesar, Colombia', Country_Region='Colombia', Confirmed='4858', Deaths='104', Recovered='2327', Active='2427.0', Incidence_Rate='404.63978063826136', Case_Fatality_Ratio='2.140798682585426')
# CovidData(Combined_Key='Choco, Colombia', Country_Region='Colombia', Confirmed='3404', Deaths='121', Recovered='2658', Active='625.0', Incidence_Rate='636.4686832726908', Case_Fatality_Ratio='3.554641598119859')
# CovidData(Combined_Key='Cordoba, Colombia', Country_Region='Colombia', Confirmed='11623', Deaths='903', Recovered='5105', Active='5615.0', Incidence_Rate='651.2276282326759', Case_Fatality_Ratio='7.769078551148585')
# CovidData(Combined_Key='Cundinamarca, Colombia', Country_Region='Colombia', Confirmed='13031', Deaths='353', Recovered='7186', Active='5492.0', Incidence_Rate='446.41083088391474', Case_Fatality_Ratio='2.7089248714603635')
# CovidData(Combined_Key='Guainia, Colombia', Country_Region='Colombia', Confirmed='20', Deaths='1', Recovered='13', Active='6.0', Incidence_Rate='41.56794280251071', Case_Fatality_Ratio='5.0')
# CovidData(Combined_Key='Guaviare, Colombia', Country_Region='Colombia', Confirmed='176', Deaths='0', Recovered='69', Active='107.0', Incidence_Rate='212.6451363466116', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Huila, Colombia', Country_Region='Colombia', Confirmed='1998', Deaths='54', Recovered='691', Active='1253.0', Incidence_Rate='181.5726481434696', Case_Fatality_Ratio='2.7027027027027017')
# CovidData(Combined_Key='La Guajira, Colombia', Country_Region='Colombia', Confirmed='3062', Deaths='155', Recovered='1797', Active='1110.0', Incidence_Rate='347.7332606523121', Case_Fatality_Ratio='5.062050947093403')
# CovidData(Combined_Key='Magdalena, Colombia', Country_Region='Colombia', Confirmed='9117', Deaths='458', Recovered='5278', Active='3381.0', Incidence_Rate='679.4877719031767', Case_Fatality_Ratio='5.023582318745201')
# CovidData(Combined_Key='Meta, Colombia', Country_Region='Colombia', Confirmed='4583', Deaths='70', Recovered='2462', Active='2051.0', Incidence_Rate='440.79090372234117', Case_Fatality_Ratio='1.5273838097316168')
# CovidData(Combined_Key='Narino, Colombia', Country_Region='Colombia', Confirmed='10404', Deaths='362', Recovered='6363', Active='3679.0', Incidence_Rate='638.0504749195384', Case_Fatality_Ratio='3.479430988081507')
# CovidData(Combined_Key='Norte de Santander, Colombia', Country_Region='Colombia', Confirmed='5492', Deaths='298', Recovered='2200', Active='2994.0', Incidence_Rate='368.17325863501037', Case_Fatality_Ratio='5.426074289876183')
# CovidData(Combined_Key='Putumayo, Colombia', Country_Region='Colombia', Confirmed='1638', Deaths='75', Recovered='604', Active='959.0', Incidence_Rate='470.44361856730103', Case_Fatality_Ratio='4.5787545787545785')
# CovidData(Combined_Key='Quindio, Colombia', Country_Region='Colombia', Confirmed='558', Deaths='13', Recovered='269', Active='276.0', Incidence_Rate='103.35170697012802', Case_Fatality_Ratio='2.3297491039426523')
# CovidData(Combined_Key='Risaralda, Colombia', Country_Region='Colombia', Confirmed='2982', Deaths='55', Recovered='1167', Active='1760.0', Incidence_Rate='316.09040058257307', Case_Fatality_Ratio='1.844399731723676')
# CovidData(Combined_Key='San Andres y Providencia, Colombia', Country_Region='Colombia', Confirmed='59', Deaths='0', Recovered='34', Active='25.0', Incidence_Rate='96.27937336814621', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Santander, Colombia', Country_Region='Colombia', Confirmed='8060', Deaths='304', Recovered='2687', Active='5069.0', Incidence_Rate='368.9062387720457', Case_Fatality_Ratio='3.771712158808933')
# CovidData(Combined_Key='Sucre, Colombia', Country_Region='Colombia', Confirmed='7878', Deaths='402', Recovered='4924', Active='2552.0', Incidence_Rate='870.6290344505188', Case_Fatality_Ratio='5.102817974105103')
# CovidData(Combined_Key='Tolima, Colombia', Country_Region='Colombia', Confirmed='3952', Deaths='91', Recovered='2026', Active='1835.0', Incidence_Rate='297.1010842836384', Case_Fatality_Ratio='2.3026315789473686')
# CovidData(Combined_Key='Valle del Cauca, Colombia', Country_Region='Colombia', Confirmed='34585', Deaths='1298', Recovered='20248', Active='13039.0', Incidence_Rate='772.6961768016432', Case_Fatality_Ratio='3.7530721411016335')
# CovidData(Combined_Key='Vaupes, Colombia', Country_Region='Colombia', Confirmed='137', Deaths='1', Recovered='60', Active='76.0', Incidence_Rate='335.8090055641346', Case_Fatality_Ratio='0.7299270072992701')
# CovidData(Combined_Key='Vichada, Colombia', Country_Region='Colombia', Confirmed='6', Deaths='0', Recovered='2', Active='4.0', Incidence_Rate='5.565449688334818', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Comoros', Country_Region='Comoros', Confirmed='399', Deaths='7', Recovered='379', Active='13.0', Incidence_Rate='45.883428492574126', Case_Fatality_Ratio='1.7543859649122806')
# CovidData(Combined_Key='Congo (Brazzaville)', Country_Region='Congo (Brazzaville)', Confirmed='3745', Deaths='60', Recovered='1625', Active='2060.0', Incidence_Rate='67.86766150328775', Case_Fatality_Ratio='1.6021361815754338')
# CovidData(Combined_Key='Congo (Kinshasa)', Country_Region='Congo (Kinshasa)', Confirmed='9538', Deaths='225', Recovered='8421', Active='892.0', Incidence_Rate='10.649676729051725', Case_Fatality_Ratio='2.358985112182848')
# CovidData(Combined_Key='Costa Rica', Country_Region='Costa Rica', Confirmed='25057', Deaths='263', Recovered='8189', Active='16605.0', Incidence_Rate='491.8814145109434', Case_Fatality_Ratio='1.0496068962764895')
# CovidData(Combined_Key="Cote d'Ivoire", Country_Region="Cote d'Ivoire", Confirmed='16847', Deaths='105', Recovered='13321', Active='3421.0', Incidence_Rate='63.86695111791806', Case_Fatality_Ratio='0.6232563661185968')
# CovidData(Combined_Key='Croatia', Country_Region='Croatia', Confirmed='5870', Deaths='160', Recovered='5024', Active='686.0', Incidence_Rate='142.9870108358334', Case_Fatality_Ratio='2.7257240204429305')
# CovidData(Combined_Key='Cuba', Country_Region='Cuba', Confirmed='3128', Deaths='88', Recovered='2504', Active='536.0', Incidence_Rate='27.616368383990412', Case_Fatality_Ratio='2.8132992327365733')
# CovidData(Combined_Key='Cyprus', Country_Region='Cyprus', Confirmed='1291', Deaths='20', Recovered='870', Active='401.0', Incidence_Rate='106.92742270124675', Case_Fatality_Ratio='1.5491866769945783')
# CovidData(Combined_Key='Czechia', Country_Region='Czechia', Confirmed='19075', Deaths='391', Recovered='13407', Active='5277.0', Incidence_Rate='178.1215058536843', Case_Fatality_Ratio='2.0498034076015728')
# CovidData(Combined_Key='Faroe Islands, Denmark', Country_Region='Denmark', Confirmed='339', Deaths='0', Recovered='225', Active='114.0', Incidence_Rate='693.7480814488898', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Greenland, Denmark', Country_Region='Denmark', Confirmed='14', Deaths='0', Recovered='14', Active='0.0', Incidence_Rate='24.660043683505954', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Denmark', Country_Region='Denmark', Confirmed='15070', Deaths='621', Recovered='13066', Active='1383.0', Incidence_Rate='260.17734530367807', Case_Fatality_Ratio='4.120769741207697')
# CovidData(Combined_Key='Diamond Princess', Country_Region='Diamond Princess', Confirmed='712', Deaths='13', Recovered='651', Active='48.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='1.8258426966292127')
# CovidData(Combined_Key='Djibouti', Country_Region='Djibouti', Confirmed='5358', Deaths='59', Recovered='5150', Active='149.0', Incidence_Rate='542.3065945210637', Case_Fatality_Ratio='1.101157148189623')
# CovidData(Combined_Key='Dominica', Country_Region='Dominica', Confirmed='18', Deaths='0', Recovered='18', Active='0.0', Incidence_Rate='25.003125390673837', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Dominican Republic', Country_Region='Dominican Republic', Confirmed='82224', Deaths='1371', Recovered='47095', Active='33758.0', Incidence_Rate='757.9713094806149', Case_Fatality_Ratio='1.6673963806187977')
# CovidData(Combined_Key='Ecuador', Country_Region='Ecuador', Confirmed='97110', Deaths='5984', Recovered='78887', Active='12239.0', Incidence_Rate='550.414723976453', Case_Fatality_Ratio='6.162084234373393')
# CovidData(Combined_Key='Egypt', Country_Region='Egypt', Confirmed='95963', Deaths='5085', Recovered='55901', Active='34977.0', Incidence_Rate='93.7739383694846', Case_Fatality_Ratio='5.298917291039254')
# CovidData(Combined_Key='El Salvador', Country_Region='El Salvador', Confirmed='21644', Deaths='577', Recovered='10056', Active='11011.0', Incidence_Rate='333.693019997376', Case_Fatality_Ratio='2.6658658288671218')
# CovidData(Combined_Key='Equatorial Guinea', Country_Region='Equatorial Guinea', Confirmed='4821', Deaths='83', Recovered='2182', Active='2556.0', Incidence_Rate='343.6244863630046', Case_Fatality_Ratio='1.7216345156606514')
# CovidData(Combined_Key='Eritrea', Country_Region='Eritrea', Confirmed='285', Deaths='0', Recovered='248', Active='37.0', Incidence_Rate='8.03625733731443', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Estonia', Country_Region='Estonia', Confirmed='2174', Deaths='63', Recovered='1975', Active='136.0', Incidence_Rate='163.88511758794883', Case_Fatality_Ratio='2.8978840846366145')
# CovidData(Combined_Key='Eswatini', Country_Region='Eswatini', Confirmed='3525', Deaths='63', Recovered='1910', Active='1552.0', Incidence_Rate='303.83635417061726', Case_Fatality_Ratio='1.7872340425531914')
# CovidData(Combined_Key='Ethiopia', Country_Region='Ethiopia', Confirmed='25118', Deaths='463', Recovered='11034', Active='13621.0', Incidence_Rate='21.848657935443782', Case_Fatality_Ratio='1.8432996257663827')
# CovidData(Combined_Key='Fiji', Country_Region='Fiji', Confirmed='27', Deaths='1', Recovered='18', Active='8.0', Incidence_Rate='3.0119003529501005', Case_Fatality_Ratio='3.703703703703704')
# CovidData(Combined_Key='Finland', Country_Region='Finland', Confirmed='7642', Deaths='333', Recovered='7050', Active='259.0', Incidence_Rate='137.9243628713824', Case_Fatality_Ratio='4.357498037163047')
# CovidData(Combined_Key='French Guiana, France', Country_Region='France', Confirmed='8423', Deaths='50', Recovered='7713', Active='660.0', Incidence_Rate='2820.056113190617', Case_Fatality_Ratio='0.5936127270568681')
# CovidData(Combined_Key='French Polynesia, France', Country_Region='France', Confirmed='139', Deaths='0', Recovered='64', Active='75.0', Incidence_Rate='49.4830974283029', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Guadeloupe, France', Country_Region='France', Confirmed='367', Deaths='14', Recovered='289', Active='64.0', Incidence_Rate='91.72087862103784', Case_Fatality_Ratio='3.8147138964577656')
# CovidData(Combined_Key='Martinique, France', Country_Region='France', Confirmed='336', Deaths='16', Recovered='98', Active='222.0', Incidence_Rate='89.53672737931862', Case_Fatality_Ratio='4.761904761904762')
# CovidData(Combined_Key='Mayotte, France', Country_Region='France', Confirmed='3091', Deaths='39', Recovered='2835', Active='217.0', Incidence_Rate='1133.0105236920529', Case_Fatality_Ratio='1.2617275962471692')
# CovidData(Combined_Key='New Caledonia, France', Country_Region='France', Confirmed='23', Deaths='0', Recovered='22', Active='1.0', Incidence_Rate='8.056295995320342', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Reunion, France', Country_Region='France', Confirmed='734', Deaths='5', Recovered='631', Active='98.0', Incidence_Rate='81.98296005397027', Case_Fatality_Ratio='0.6811989100817438')
# CovidData(Combined_Key='Saint Barthelemy, France', Country_Region='France', Confirmed='13', Deaths='0', Recovered='6', Active='7.0', Incidence_Rate='131.51239251390996', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Saint Pierre and Miquelon, France', Country_Region='France', Confirmed='4', Deaths='0', Recovered='1', Active='3.0', Incidence_Rate='69.02502157031924', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='St Martin, France', Country_Region='France', Confirmed='84', Deaths='4', Recovered='44', Active='36.0', Incidence_Rate='217.28446157427769', Case_Fatality_Ratio='4.761904761904762')
# CovidData(Combined_Key='France', Country_Region='France', Confirmed='230874', Deaths='30247', Recovered='71906', Active='128721.0', Incidence_Rate='353.7024329256253', Case_Fatality_Ratio='13.101085440543327')
# CovidData(Combined_Key='Gabon', Country_Region='Gabon', Confirmed='8077', Deaths='51', Recovered='5920', Active='2106.0', Incidence_Rate='362.8925007907525', Case_Fatality_Ratio='0.6314225578804011')
# CovidData(Combined_Key='Gambia', Country_Region='Gambia', Confirmed='1477', Deaths='33', Recovered='247', Active='1197.0', Incidence_Rate='61.11730881909938', Case_Fatality_Ratio='2.2342586323628977')
# CovidData(Combined_Key='Georgia', Country_Region='Georgia', Confirmed='1278', Deaths='17', Recovered='1058', Active='203.0', Incidence_Rate='32.036699317528054', Case_Fatality_Ratio='1.330203442879499')
# CovidData(Combined_Key='Baden-Wurttemberg, Germany', Country_Region='Germany', Confirmed='38165', Deaths='1859', Recovered='35200', Active='1106.0', Incidence_Rate='344.77515898818865', Case_Fatality_Ratio='4.870955063539894')
# CovidData(Combined_Key='Bayern, Germany', Country_Region='Germany', Confirmed='52203', Deaths='2627', Recovered='48200', Active='1376.0', Incidence_Rate='399.2055806650612', Case_Fatality_Ratio='5.032277838438404')
# CovidData(Combined_Key='Berlin, Germany', Country_Region='Germany', Confirmed='9975', Deaths='224', Recovered='9088', Active='663.0', Incidence_Rate='273.67561579071264', Case_Fatality_Ratio='2.245614035087719')
# CovidData(Combined_Key='Brandenburg, Germany', Country_Region='Germany', Confirmed='3667', Deaths='175', Recovered='3400', Active='92.0', Incidence_Rate='145.98412288304112', Case_Fatality_Ratio='4.772293427870193')
# CovidData(Combined_Key='Bremen, Germany', Country_Region='Germany', Confirmed='1825', Deaths='56', Recovered='1709', Active='60.0', Incidence_Rate='267.2089911066991', Case_Fatality_Ratio='3.068493150684932')
# CovidData(Combined_Key='Hamburg, Germany', Country_Region='Germany', Confirmed='5773', Deaths='262', Recovered='5100', Active='411.0', Incidence_Rate='313.54909001243226', Case_Fatality_Ratio='4.53836826606617')
# CovidData(Combined_Key='Hessen, Germany', Country_Region='Germany', Confirmed='12876', Deaths='526', Recovered='11500', Active='850.0', Incidence_Rate='205.49620966741887', Case_Fatality_Ratio='4.085119602360981')
# CovidData(Combined_Key='Mecklenburg-Vorpommern, Germany', Country_Region='Germany', Confirmed='954', Deaths='20', Recovered='848', Active='86.0', Incidence_Rate='59.26662214422166', Case_Fatality_Ratio='2.0964360587002098')
# CovidData(Combined_Key='Niedersachsen, Germany', Country_Region='Germany', Confirmed='15122', Deaths='655', Recovered='13700', Active='767.0', Incidence_Rate='189.4406327482497', Case_Fatality_Ratio='4.33143764052374')
# CovidData(Combined_Key='Nordrhein-Westfalen, Germany', Country_Region='Germany', Confirmed='52588', Deaths='1765', Recovered='46600', Active='4223.0', Incidence_Rate='293.2527934659521', Case_Fatality_Ratio='3.356278999011181')
# CovidData(Combined_Key='Rheinland-Pfalz, Germany', Country_Region='Germany', Confirmed='7937', Deaths='239', Recovered='7250', Active='448.0', Incidence_Rate='194.3036257932984', Case_Fatality_Ratio='3.0112133047751035')
# CovidData(Combined_Key='Saarland, Germany', Country_Region='Germany', Confirmed='2952', Deaths='174', Recovered='2694', Active='84.0', Incidence_Rate='298.0285893414396', Case_Fatality_Ratio='5.894308943089431')
# CovidData(Combined_Key='Sachsen, Germany', Country_Region='Germany', Confirmed='5682', Deaths='225', Recovered='5305', Active='152.0', Incidence_Rate='139.33515892962544', Case_Fatality_Ratio='3.9598732840549102')
# CovidData(Combined_Key='Sachsen-Anhalt, Germany', Country_Region='Germany', Confirmed='2093', Deaths='64', Recovered='1937', Active='92.0', Incidence_Rate='94.7778878161282', Case_Fatality_Ratio='3.057811753463928')
# CovidData(Combined_Key='Schleswig-Holstein, Germany', Country_Region='Germany', Confirmed='3714', Deaths='158', Recovered='3260', Active='296.0', Incidence_Rate='128.21433404494476', Case_Fatality_Ratio='4.2541733979536875')
# CovidData(Combined_Key='Thuringen, Germany', Country_Region='Germany', Confirmed='3453', Deaths='184', Recovered='3200', Active='69.0', Incidence_Rate='161.11835643411902', Case_Fatality_Ratio='5.328699681436431')
# CovidData(Combined_Key='Unknown, Germany', Country_Region='Germany', Confirmed='1880', Deaths='0', Recovered='0', Active='1880.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Ghana', Country_Region='Ghana', Confirmed='41572', Deaths='223', Recovered='39320', Active='2029.0', Incidence_Rate='133.78841303906015', Case_Fatality_Ratio='0.5364187433849706')
# CovidData(Combined_Key='Greece', Country_Region='Greece', Confirmed='6177', Deaths='216', Recovered='1347', Active='4614.0', Incidence_Rate='59.262849590369655', Case_Fatality_Ratio='3.4968431277319088')
# CovidData(Combined_Key='Grenada', Country_Region='Grenada', Confirmed='24', Deaths='0', Recovered='23', Active='1.0', Incidence_Rate='21.329730978768033', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Guatemala', Country_Region='Guatemala', Confirmed='59089', Deaths='2267', Recovered='47394', Active='9428.0', Incidence_Rate='329.81931300304365', Case_Fatality_Ratio='3.836585489685052')
# CovidData(Combined_Key='Guinea', Country_Region='Guinea', Confirmed='8116', Deaths='50', Recovered='7060', Active='1006.0', Incidence_Rate='61.79950158351705', Case_Fatality_Ratio='0.6160670280926565')
# CovidData(Combined_Key='Guinea-Bissau', Country_Region='Guinea-Bissau', Confirmed='2088', Deaths='29', Recovered='1015', Active='1044.0', Incidence_Rate='106.0976687984439', Case_Fatality_Ratio='1.3888888888888888')
# CovidData(Combined_Key='Guyana', Country_Region='Guyana', Confirmed='623', Deaths='22', Recovered='191', Active='410.0', Incidence_Rate='79.20575570300511', Case_Fatality_Ratio='3.531300160513644')
# CovidData(Combined_Key='Haiti', Country_Region='Haiti', Confirmed='7743', Deaths='187', Recovered='5123', Active='2433.0', Incidence_Rate='67.90596440282172', Case_Fatality_Ratio='2.415084592535193')
# CovidData(Combined_Key='Holy See', Country_Region='Holy See', Confirmed='12', Deaths='0', Recovered='12', Active='0.0', Incidence_Rate='1483.3127317676144', Case_Fatality_Ratio='0.0')
# ...
# CovidData(Combined_Key='Big Horn, Wyoming, US', Country_Region='US', Confirmed='37', Deaths='0', Recovered='0', Active='37.0', Incidence_Rate='313.8252756573367', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Campbell, Wyoming, US', Country_Region='US', Confirmed='132', Deaths='0', Recovered='0', Active='132.0', Incidence_Rate='284.84495371269503', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Carbon, Wyoming, US', Country_Region='US', Confirmed='105', Deaths='0', Recovered='0', Active='105.0', Incidence_Rate='709.4594594594595', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Converse, Wyoming, US', Country_Region='US', Confirmed='31', Deaths='0', Recovered='0', Active='31.0', Incidence_Rate='224.2801331211113', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Crook, Wyoming, US', Country_Region='US', Confirmed='10', Deaths='0', Recovered='0', Active='10.0', Incidence_Rate='131.85654008438817', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Fremont, Wyoming, US', Country_Region='US', Confirmed='500', Deaths='0', Recovered='0', Active='500.0', Incidence_Rate='1273.528437890018', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Goshen, Wyoming, US', Country_Region='US', Confirmed='34', Deaths='0', Recovered='0', Active='34.0', Incidence_Rate='257.36128983422907', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Hot Springs, Wyoming, US', Country_Region='US', Confirmed='23', Deaths='0', Recovered='0', Active='23.0', Incidence_Rate='521.1874008610922', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Johnson, Wyoming, US', Country_Region='US', Confirmed='24', Deaths='1', Recovered='0', Active='23.0', Incidence_Rate='284.1918294849023', Case_Fatality_Ratio='4.166666666666667')
# CovidData(Combined_Key='Laramie, Wyoming, US', Country_Region='US', Confirmed='504', Deaths='0', Recovered='0', Active='504.0', Incidence_Rate='506.5326633165829', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Lincoln, Wyoming, US', Country_Region='US', Confirmed='100', Deaths='0', Recovered='0', Active='100.0', Incidence_Rate='504.2864346949067', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Natrona, Wyoming, US', Country_Region='US', Confirmed='238', Deaths='0', Recovered='0', Active='238.0', Incidence_Rate='298.0290014776228', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Niobrara, Wyoming, US', Country_Region='US', Confirmed='2', Deaths='0', Recovered='0', Active='2.0', Incidence_Rate='84.88964346349746', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Park, Wyoming, US', Country_Region='US', Confirmed='135', Deaths='0', Recovered='0', Active='135.0', Incidence_Rate='462.4237857093924', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Platte, Wyoming, US', Country_Region='US', Confirmed='5', Deaths='0', Recovered='0', Active='5.0', Incidence_Rate='59.57345406886692', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Sheridan, Wyoming, US', Country_Region='US', Confirmed='73', Deaths='0', Recovered='0', Active='73.0', Incidence_Rate='239.46203050680663', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Sublette, Wyoming, US', Country_Region='US', Confirmed='40', Deaths='0', Recovered='0', Active='40.0', Incidence_Rate='406.87620791374223', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Sweetwater, Wyoming, US', Country_Region='US', Confirmed='266', Deaths='0', Recovered='0', Active='266.0', Incidence_Rate='628.2030087617787', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Teton, Wyoming, US', Country_Region='US', Confirmed='373', Deaths='0', Recovered='0', Active='373.0', Incidence_Rate='1589.669280600068', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Uinta, Wyoming, US', Country_Region='US', Confirmed='278', Deaths='0', Recovered='0', Active='278.0', Incidence_Rate='1374.4685058835162', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Unassigned, Wyoming, US', Country_Region='US', Confirmed='0', Deaths='28', Recovered='0', Active='-28.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='-99.0')
# CovidData(Combined_Key='Washakie, Wyoming, US', Country_Region='US', Confirmed='82', Deaths='0', Recovered='0', Active='82.0', Incidence_Rate='1050.6085842408713', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Weston, Wyoming, US', Country_Region='US', Confirmed='5', Deaths='0', Recovered='0', Active='5.0', Incidence_Rate='72.18131947452', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Uganda', Country_Region='Uganda', Confirmed='1332', Deaths='9', Recovered='1139', Active='184.0', Incidence_Rate='2.912048271791172', Case_Fatality_Ratio='0.6756756756756757')
# CovidData(Combined_Key='Cherkasy Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1049', Deaths='37', Recovered='789', Active='223.0', Incidence_Rate='86.95644965685774', Case_Fatality_Ratio='3.5271687321258343')
# CovidData(Combined_Key='Chernihiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1080', Deaths='18', Recovered='564', Active='498.0', Incidence_Rate='107.38308418137798', Case_Fatality_Ratio='1.6666666666666667')
# CovidData(Combined_Key='Chernivtsi Oblast, Ukraine', Country_Region='Ukraine', Confirmed='6980', Deaths='232', Recovered='5312', Active='1436.0', Incidence_Rate='771.8045852711379', Case_Fatality_Ratio='3.32378223495702')
# CovidData(Combined_Key='Crimea Republic*, Ukraine', Country_Region='Ukraine', Confirmed='1557', Deaths='18', Recovered='1077', Active='462.0', Incidence_Rate='81.35939690583473', Case_Fatality_Ratio='1.1560693641618498')
# CovidData(Combined_Key='Dnipropetrovsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1602', Deaths='36', Recovered='1152', Active='414.0', Incidence_Rate='49.96137505430415', Case_Fatality_Ratio='2.247191011235955')
# CovidData(Combined_Key='Donetsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1011', Deaths='13', Recovered='780', Active='218.0', Incidence_Rate='24.268459572130972', Case_Fatality_Ratio='1.2858555885262115')
# CovidData(Combined_Key='Ivano-Frankivsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='6039', Deaths='160', Recovered='2372', Active='3507.0', Incidence_Rate='439.7590536915293', Case_Fatality_Ratio='2.649445272396092')
# CovidData(Combined_Key='Kharkiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='5169', Deaths='150', Recovered='2552', Active='2467.0', Incidence_Rate='193.19045686235376', Case_Fatality_Ratio='2.9019152640742885')
# CovidData(Combined_Key='Kherson Oblast, Ukraine', Country_Region='Ukraine', Confirmed='276', Deaths='5', Recovered='213', Active='58.0', Incidence_Rate='26.59882040013877', Case_Fatality_Ratio='1.8115942028985508')
# CovidData(Combined_Key='Khmelnytskyi Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1413', Deaths='31', Recovered='1045', Active='337.0', Incidence_Rate='111.72565934348326', Case_Fatality_Ratio='2.193913658881812')
# CovidData(Combined_Key='Kiev, Ukraine', Country_Region='Ukraine', Confirmed='9869', Deaths='147', Recovered='3278', Active='6444.0', Incidence_Rate='334.45167412227187', Case_Fatality_Ratio='1.4895126152599047')
# CovidData(Combined_Key='Kiev Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4307', Deaths='71', Recovered='3021', Active='1215.0', Incidence_Rate='243.61686482572938', Case_Fatality_Ratio='1.6484792198746228')
# CovidData(Combined_Key='Kirovohrad Oblast, Ukraine', Country_Region='Ukraine', Confirmed='728', Deaths='39', Recovered='655', Active='34.0', Incidence_Rate='76.99230817228933', Case_Fatality_Ratio='5.357142857142857')
# CovidData(Combined_Key='Luhansk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='160', Deaths='1', Recovered='117', Active='42.0', Incidence_Rate='7.435521250952095', Case_Fatality_Ratio='0.625')
# CovidData(Combined_Key='Lviv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='11308', Deaths='310', Recovered='3040', Active='7958.0', Incidence_Rate='448.3705726478884', Case_Fatality_Ratio='2.7414220021223907')
# CovidData(Combined_Key='Mykolaiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='744', Deaths='18', Recovered='493', Active='233.0', Incidence_Rate='29.50015087106729', Case_Fatality_Ratio='2.419354838709677')
# CovidData(Combined_Key='Odessa Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4458', Deaths='73', Recovered='1463', Active='2922.0', Incidence_Rate='187.28668726904246', Case_Fatality_Ratio='1.6375056078959174')
# CovidData(Combined_Key='Poltava Oblast, Ukraine', Country_Region='Ukraine', Confirmed='514', Deaths='15', Recovered='372', Active='127.0', Incidence_Rate='36.70277677214074', Case_Fatality_Ratio='2.9182879377431905')
# CovidData(Combined_Key='Rivne Oblast, Ukraine', Country_Region='Ukraine', Confirmed='7114', Deaths='106', Recovered='5407', Active='1601.0', Incidence_Rate='614.7061136212619', Case_Fatality_Ratio='1.490019679505201')
# CovidData(Combined_Key='Sevastopol*, Ukraine', Country_Region='Ukraine', Confirmed='399', Deaths='11', Recovered='321', Active='67.0', Incidence_Rate='90.02484144120972', Case_Fatality_Ratio='2.7568922305764407')
# CovidData(Combined_Key='Sumy Oblast, Ukraine', Country_Region='Ukraine', Confirmed='716', Deaths='10', Recovered='426', Active='280.0', Incidence_Rate='66.20936585113249', Case_Fatality_Ratio='1.3966480446927374')
# CovidData(Combined_Key='Ternopil Oblast, Ukraine', Country_Region='Ukraine', Confirmed='3413', Deaths='44', Recovered='2255', Active='1114.0', Incidence_Rate='326.3283802428388', Case_Fatality_Ratio='1.2891883973044242')
# CovidData(Combined_Key='Vinnytsia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='3043', Deaths='63', Recovered='2303', Active='677.0', Incidence_Rate='195.01484881382527', Case_Fatality_Ratio='2.0703253368386463')
# CovidData(Combined_Key='Volyn Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4423', Deaths='95', Recovered='3260', Active='1068.0', Incidence_Rate='427.2067843103165', Case_Fatality_Ratio='2.147863441103324')
# CovidData(Combined_Key='Zakarpattia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='5946', Deaths='226', Recovered='2563', Active='3157.0', Incidence_Rate='473.1055488454029', Case_Fatality_Ratio='3.800874537504205')
# CovidData(Combined_Key='Zaporizhia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='971', Deaths='22', Recovered='680', Active='269.0', Incidence_Rate='56.92223636973308', Case_Fatality_Ratio='2.265705458290422')
# CovidData(Combined_Key='Zhytomyr Oblast, Ukraine', Country_Region='Ukraine', Confirmed='2215', Deaths='48', Recovered='1574', Active='593.0', Incidence_Rate='181.52865981037425', Case_Fatality_Ratio='2.1670428893905203')
# CovidData(Combined_Key='United Arab Emirates', Country_Region='United Arab Emirates', Confirmed='63212', Deaths='358', Recovered='57193', Active='5661.0', Incidence_Rate='639.124807894524', Case_Fatality_Ratio='0.5663481617414415')
# CovidData(Combined_Key='Anguilla, United Kingdom', Country_Region='United Kingdom', Confirmed='3', Deaths='0', Recovered='3', Active='0.0', Incidence_Rate='19.99733368884149', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Bermuda, United Kingdom', Country_Region='United Kingdom', Confirmed='159', Deaths='9', Recovered='145', Active='5.0', Incidence_Rate='255.32734893131854', Case_Fatality_Ratio='5.660377358490566')
# CovidData(Combined_Key='British Virgin Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='9', Deaths='1', Recovered='7', Active='1.0', Incidence_Rate='29.76485762476436', Case_Fatality_Ratio='11.111111111111107')
# CovidData(Combined_Key='Cayman Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='203', Deaths='1', Recovered='202', Active='0.0', Incidence_Rate='308.8861838101035', Case_Fatality_Ratio='0.4926108374384237')
# CovidData(Combined_Key='Channel Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='603', Deaths='47', Recovered='545', Active='11.0', Incidence_Rate='353.66776344729294', Case_Fatality_Ratio='7.794361525704807')
# CovidData(Combined_Key='England, United Kingdom', Country_Region='United Kingdom', Confirmed='270971', Deaths='42072', Recovered='0', Active='228899.0', Incidence_Rate='484.07387293398034', Case_Fatality_Ratio='15.526384742278696')
# CovidData(Combined_Key='Falkland Islands (Malvinas), United Kingdom', Country_Region='United Kingdom', Confirmed='13', Deaths='0', Recovered='13', Active='0.0', Incidence_Rate='373.2414585127763', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Gibraltar, United Kingdom', Country_Region='United Kingdom', Confirmed='203', Deaths='0', Recovered='187', Active='16.0', Incidence_Rate='602.5348015790568', Case_Fatality_Ratio='0.0')
# CovidData(Combined_Key='Isle of Man, United Kingdom', Country_Region='United Kingdom', Confirmed='336', Deaths='24', Recovered='312', Active='0.0', Incidence_Rate='395.14535704205474', Case_Fatality_Ratio='7.142857142857142')
# CovidData(Combined_Key='Montserrat, United Kingdom', Country_Region='United Kingdom', Confirmed='13', Deaths='1', Recovered='12', Active='0.0', Incidence_Rate='260.05201040208044', Case_Fatality_Ratio='7.6923076923076925')
# CovidData(Combined_Key='Northern Ireland, United Kingdom', Country_Region='United Kingdom', Confirmed='6217', Deaths='557', Recovered='0', Active='5660.0', Incidence_Rate='330.41028911564626', Case_Fatality_Ratio='8.959305131092169')
# CovidData(Combined_Key='Scotland, United Kingdom', Country_Region='United Kingdom', Confirmed='19126', Deaths='2491', Recovered='0', Active='16635.0', Incidence_Rate='350.08145260190724', Case_Fatality_Ratio='13.024155599707205')
# CovidData(Combined_Key='Turks and Caicos Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='241', Deaths='2', Recovered='46', Active='193.0', Incidence_Rate='622.4495066893951', Case_Fatality_Ratio='0.8298755186721992')
# CovidData(Combined_Key='Unknown, United Kingdom', Country_Region='United Kingdom', Confirmed='0', Deaths='0', Recovered='0', Active='0.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='-99.0')
# CovidData(Combined_Key='Wales, United Kingdom', Country_Region='United Kingdom', Confirmed='17484', Deaths='1586', Recovered='0', Active='15898.0', Incidence_Rate='557.0636589562225', Case_Fatality_Ratio='9.071150766415009')
# CovidData(Combined_Key='Uruguay', Country_Region='Uruguay', Confirmed='1393', Deaths='37', Recovered='1163', Active='193.0', Incidence_Rate='40.101021179845155', Case_Fatality_Ratio='2.656137832017229')
# CovidData(Combined_Key='Uzbekistan', Country_Region='Uzbekistan', Confirmed='32654', Deaths='211', Recovered='25659', Active='6784.0', Incidence_Rate='97.56433071493583', Case_Fatality_Ratio='0.6461689226434739')
# CovidData(Combined_Key='Venezuela', Country_Region='Venezuela', Confirmed='29088', Deaths='247', Recovered='21042', Active='7799.0', Incidence_Rate='102.29307324184748', Case_Fatality_Ratio='0.8491474147414741')
# CovidData(Combined_Key='Vietnam', Country_Region='Vietnam', Confirmed='883', Deaths='18', Recovered='409', Active='456.0', Incidence_Rate='0.9071428541342133', Case_Fatality_Ratio='2.0385050962627407')
# CovidData(Combined_Key='West Bank and Gaza', Country_Region='West Bank and Gaza', Confirmed='15184', Deaths='105', Recovered='8369', Active='6710.0', Incidence_Rate='297.6428505340478', Case_Fatality_Ratio='0.6915173867228662')
# CovidData(Combined_Key='Western Sahara', Country_Region='Western Sahara', Confirmed='10', Deaths='1', Recovered='8', Active='1.0', Incidence_Rate='1.674116485025028', Case_Fatality_Ratio='10.0')
# CovidData(Combined_Key='Yemen', Country_Region='Yemen', Confirmed='1841', Deaths='528', Recovered='937', Active='376.0', Incidence_Rate='6.172473597504027', Case_Fatality_Ratio='28.680065181966324')
# CovidData(Combined_Key='Zambia', Country_Region='Zambia', Confirmed='8501', Deaths='246', Recovered='7233', Active='1022.0', Incidence_Rate='46.24140745332506', Case_Fatality_Ratio='2.8937772026820374')
# CovidData(Combined_Key='Zimbabwe', Country_Region='Zimbabwe', Confirmed='4893', Deaths='122', Recovered='1620', Active='3151.0', Incidence_Rate='32.92083719445033', Case_Fatality_Ratio='2.493357858164725')

# %%
test = []
for x in data_named[0:1] :
    col_type = []
    for i in  range(len_col_data_named) :
         
        col_type.append(type(x.Combined_Key))    
        col_type.append(type (x.Country_Region))   
        col_type.append(type  (x.Confirmed ))
        col_type.append(type  (x.Deaths))  
        col_type.append(type (x.Recovered )) 
        col_type.append(type  (x.Active )) 
        col_type.append(type (x.Incidence_Rate))   
        col_type.append(type (x.Case_Fatality_Ratio)) 
    test.append(col_type)

# %%
#This is a range
#start at row 1. End at row 2
data_named[1:2]
# Out:
# [CovidData(Combined_Key='Albania', Country_Region='Albania', Confirmed='6817', Deaths='208', Recovered='3552', Active='3057.0', Incidence_Rate='236.882340676906', Case_Fatality_Ratio='3.0511955405603635')]

# %%
data_named[0:1]
# Out:
# [CovidData(Combined_Key='Afghanistan', Country_Region='Afghanistan', Confirmed='37345', Deaths='1354', Recovered='26694', Active='9297.0', Incidence_Rate='95.93267794278722', Case_Fatality_Ratio='3.6256526978176464')]

# %%
len(data_named)
# Out:
# 3941

# %%
for i in range(len(data_named)) :
     print(data_named[i:i+1])
# Out:
# [CovidData(Combined_Key='Afghanistan', Country_Region='Afghanistan', Confirmed='37345', Deaths='1354', Recovered='26694', Active='9297.0', Incidence_Rate='95.93267794278722', Case_Fatality_Ratio='3.6256526978176464')]
# [CovidData(Combined_Key='Albania', Country_Region='Albania', Confirmed='6817', Deaths='208', Recovered='3552', Active='3057.0', Incidence_Rate='236.882340676906', Case_Fatality_Ratio='3.0511955405603635')]
# [CovidData(Combined_Key='Algeria', Country_Region='Algeria', Confirmed='36699', Deaths='1333', Recovered='25627', Active='9739.0', Incidence_Rate='83.69014164611774', Case_Fatality_Ratio='3.6322515599880094')]
# [CovidData(Combined_Key='Andorra', Country_Region='Andorra', Confirmed='977', Deaths='53', Recovered='855', Active='69.0', Incidence_Rate='1264.4793891153822', Case_Fatality_Ratio='5.424769703172978')]
# [CovidData(Combined_Key='Angola', Country_Region='Angola', Confirmed='1762', Deaths='80', Recovered='577', Active='1105.0', Incidence_Rate='5.361119796138704', Case_Fatality_Ratio='4.540295119182747')]
# [CovidData(Combined_Key='Antigua and Barbuda', Country_Region='Antigua and Barbuda', Confirmed='92', Deaths='3', Recovered='76', Active='13.0', Incidence_Rate='93.94657299240258', Case_Fatality_Ratio='3.260869565217391')]
# [CovidData(Combined_Key='Argentina', Country_Region='Argentina', Confirmed='268574', Deaths='5213', Recovered='187283', Active='76078.0', Incidence_Rate='594.2457853971622', Case_Fatality_Ratio='1.9409920543313948')]
# [CovidData(Combined_Key='Armenia', Country_Region='Armenia', Confirmed='40794', Deaths='806', Recovered='33492', Active='6496.0', Incidence_Rate='1376.6715689682287', Case_Fatality_Ratio='1.975780752071383')]
# [CovidData(Combined_Key='Australian Capital Territory, Australia', Country_Region='Australia', Confirmed='113', Deaths='3', Recovered='110', Active='0.0', Incidence_Rate='26.395701938799345', Case_Fatality_Ratio='2.6548672566371683')]
# [CovidData(Combined_Key='New South Wales, Australia', Country_Region='Australia', Confirmed='3927', Deaths='51', Recovered='2994', Active='882.0', Incidence_Rate='48.3739837398374', Case_Fatality_Ratio='1.2987012987012987')]
# [CovidData(Combined_Key='Northern Territory, Australia', Country_Region='Australia', Confirmed='33', Deaths='0', Recovered='31', Active='2.0', Incidence_Rate='13.436482084690551', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Queensland, Australia', Country_Region='Australia', Confirmed='1089', Deaths='6', Recovered='1076', Active='7.0', Incidence_Rate='21.28824161861011', Case_Fatality_Ratio='0.5509641873278237')]
# [CovidData(Combined_Key='South Australia, Australia', Country_Region='Australia', Confirmed='459', Deaths='4', Recovered='449', Active='6.0', Incidence_Rate='26.131511528608023', Case_Fatality_Ratio='0.8714596949891068')]
# [CovidData(Combined_Key='Tasmania, Australia', Country_Region='Australia', Confirmed='230', Deaths='13', Recovered='216', Active='1.0', Incidence_Rate='42.95051353874883', Case_Fatality_Ratio='5.652173913043479')]
# [CovidData(Combined_Key='Victoria, Australia', Country_Region='Australia', Confirmed='15863', Deaths='275', Recovered='7271', Active='8317.0', Incidence_Rate='239.26454395993903', Case_Fatality_Ratio='1.73359389774948')]
# [CovidData(Combined_Key='Western Australia, Australia', Country_Region='Australia', Confirmed='644', Deaths='9', Recovered='632', Active='3.0', Incidence_Rate='24.481106971793512', Case_Fatality_Ratio='1.3975155279503106')]
# [CovidData(Combined_Key='Austria', Country_Region='Austria', Confirmed='22439', Deaths='724', Recovered='20268', Active='1447.0', Incidence_Rate='249.1450524071772', Case_Fatality_Ratio='3.2265252462230936')]
# [CovidData(Combined_Key='Azerbaijan', Country_Region='Azerbaijan', Confirmed='33824', Deaths='497', Recovered='31058', Active='2269.0', Incidence_Rate='333.5971615047576', Case_Fatality_Ratio='1.4693708609271523')]
# [CovidData(Combined_Key='Bahamas', Country_Region='Bahamas', Confirmed='1036', Deaths='15', Recovered='122', Active='899.0', Incidence_Rate='263.44698510863367', Case_Fatality_Ratio='1.4478764478764483')]
# [CovidData(Combined_Key='Bahrain', Country_Region='Bahrain', Confirmed='45264', Deaths='166', Recovered='41836', Active='3262.0', Incidence_Rate='2660.111202333357', Case_Fatality_Ratio='0.3667373630258042')]
# [CovidData(Combined_Key='Bangladesh', Country_Region='Bangladesh', Confirmed='266498', Deaths='3513', Recovered='153089', Active='109896.0', Incidence_Rate='161.81856726004008', Case_Fatality_Ratio='1.318208767045156')]
# [CovidData(Combined_Key='Barbados', Country_Region='Barbados', Confirmed='144', Deaths='7', Recovered='115', Active='22.0', Incidence_Rate='50.10944040978386', Case_Fatality_Ratio='4.861111111111111')]
# [CovidData(Combined_Key='Belarus', Country_Region='Belarus', Confirmed='69102', Deaths='595', Recovered='65893', Active='2614.0', Incidence_Rate='731.2906398248085', Case_Fatality_Ratio='0.8610459899858179')]
# [CovidData(Combined_Key='Belgium', Country_Region='Belgium', Confirmed='75647', Deaths='9900', Recovered='17883', Active='47864.0', Incidence_Rate='652.7136015550473', Case_Fatality_Ratio='13.087101933982842')]
# [CovidData(Combined_Key='Belize', Country_Region='Belize', Confirmed='210', Deaths='2', Recovered='32', Active='176.0', Incidence_Rate='52.8141119307079', Case_Fatality_Ratio='0.9523809523809524')]
# [CovidData(Combined_Key='Benin', Country_Region='Benin', Confirmed='2014', Deaths='38', Recovered='1681', Active='295.0', Incidence_Rate='16.612778245476154', Case_Fatality_Ratio='1.8867924528301887')]
# [CovidData(Combined_Key='Bhutan', Country_Region='Bhutan', Confirmed='113', Deaths='0', Recovered='97', Active='16.0', Incidence_Rate='14.644665972017028', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Bolivia', Country_Region='Bolivia', Confirmed='95071', Deaths='3827', Recovered='32830', Active='58414.0', Incidence_Rate='814.4501311527624', Case_Fatality_Ratio='4.025412586382808')]
# [CovidData(Combined_Key='Bosnia and Herzegovina', Country_Region='Bosnia and Herzegovina', Confirmed='14961', Deaths='453', Recovered='8827', Active='5681.0', Incidence_Rate='456.01474023984895', Case_Fatality_Ratio='3.0278724684178866')]
# [CovidData(Combined_Key='Botswana', Country_Region='Botswana', Confirmed='1066', Deaths='2', Recovered='80', Active='984.0', Incidence_Rate='45.33035666826131', Case_Fatality_Ratio='0.18761726078799248')]
# [CovidData(Combined_Key='Acre, Brazil', Country_Region='Brazil', Confirmed='21993', Deaths='569', Recovered='15307', Active='6117.0', Incidence_Rate='2493.7211926048967', Case_Fatality_Ratio='2.5871868321738734')]
# [CovidData(Combined_Key='Alagoas, Brazil', Country_Region='Brazil', Confirmed='69751', Deaths='1711', Recovered='63287', Active='4753.0', Incidence_Rate='2090.0071523663787', Case_Fatality_Ratio='2.45301142635948')]
# [CovidData(Combined_Key='Amapa, Brazil', Country_Region='Brazil', Confirmed='38801', Deaths='606', Recovered='26773', Active='11422.0', Incidence_Rate='4587.865408741077', Case_Fatality_Ratio='1.5618154171284244')]
# [CovidData(Combined_Key='Amazonas, Brazil', Country_Region='Brazil', Confirmed='108920', Deaths='3417', Recovered='92335', Active='13168.0', Incidence_Rate='2627.9997789893687', Case_Fatality_Ratio='3.1371648916636063')]
# [CovidData(Combined_Key='Bahia, Brazil', Country_Region='Brazil', Confirmed='203020', Deaths='4135', Recovered='184444', Active='14441.0', Incidence_Rate='1365.0179949471071', Case_Fatality_Ratio='2.036745148261255')]
# [CovidData(Combined_Key='Ceara, Brazil', Country_Region='Brazil', Confirmed='192422', Deaths='8052', Recovered='164954', Active='19416.0', Incidence_Rate='2107.0998298525265', Case_Fatality_Ratio='4.184552701874006')]
# [CovidData(Combined_Key='Distrito Federal, Brazil', Country_Region='Brazil', Confirmed='129184', Deaths='1870', Recovered='110632', Active='16682.0', Incidence_Rate='4284.328955170818', Case_Fatality_Ratio='1.4475476839237058')]
# [CovidData(Combined_Key='Espirito Santo, Brazil', Country_Region='Brazil', Confirmed='95753', Deaths='2805', Recovered='81923', Active='11025.0', Incidence_Rate='2382.7155885683005', Case_Fatality_Ratio='2.9294121333013066')]
# [CovidData(Combined_Key='Goias, Brazil', Country_Region='Brazil', Confirmed='93274', Deaths='2135', Recovered='85214', Active='5925.0', Incidence_Rate='1329.0010734710734', Case_Fatality_Ratio='2.2889551214700776')]
# [CovidData(Combined_Key='Maranhao, Brazil', Country_Region='Brazil', Confirmed='133265', Deaths='3215', Recovered='123772', Active='6278.0', Incidence_Rate='1883.5560531949645', Case_Fatality_Ratio='2.4124863992796306')]
# [CovidData(Combined_Key='Mato Grosso, Brazil', Country_Region='Brazil', Confirmed='68924', Deaths='2221', Recovered='46355', Active='20348.0', Incidence_Rate='1978.0362328115696', Case_Fatality_Ratio='3.2223898787069816')]
# [CovidData(Combined_Key='Mato Grosso do Sul, Brazil', Country_Region='Brazil', Confirmed='33509', Deaths='558', Recovered='27329', Active='5622.0', Incidence_Rate='1205.7995254384152', Case_Fatality_Ratio='1.6652242681070757')]
# [CovidData(Combined_Key='Minas Gerais, Brazil', Country_Region='Brazil', Confirmed='160485', Deaths='3783', Recovered='128957', Active='27745.0', Incidence_Rate='758.1207637224063', Case_Fatality_Ratio='2.35722964763062')]
# [CovidData(Combined_Key='Para, Brazil', Country_Region='Brazil', Confirmed='171878', Deaths='5909', Recovered='157802', Active='8167.0', Incidence_Rate='1997.9158106049554', Case_Fatality_Ratio='3.43790362931847')]
# [CovidData(Combined_Key='Paraiba, Brazil', Country_Region='Brazil', Confirmed='92897', Deaths='2071', Recovered='47111', Active='43715.0', Incidence_Rate='2311.9478304194963', Case_Fatality_Ratio='2.2293507863547797')]
# [CovidData(Combined_Key='Parana, Brazil', Country_Region='Brazil', Confirmed='97785', Deaths='2516', Recovered='58064', Active='37205.0', Incidence_Rate='855.2157402725933', Case_Fatality_Ratio='2.5729917676535257')]
# [CovidData(Combined_Key='Pernambuco, Brazil', Country_Region='Brazil', Confirmed='107375', Deaths='7049', Recovered='88252', Active='12074.0', Incidence_Rate='1123.5136790340891', Case_Fatality_Ratio='6.564842840512223')]
# [CovidData(Combined_Key='Piaui, Brazil', Country_Region='Brazil', Confirmed='62465', Deaths='1548', Recovered='61433', Active='-516.0', Incidence_Rate='1908.361381596816', Case_Fatality_Ratio='2.4781877851596894')]
# [CovidData(Combined_Key='Rio Grande do Norte, Brazil', Country_Region='Brazil', Confirmed='56572', Deaths='2019', Recovered='28243', Active='26310.0', Incidence_Rate='1613.184242396245', Case_Fatality_Ratio='3.5689033444106624')]
# [CovidData(Combined_Key='Rio Grande do Sul, Brazil', Country_Region='Brazil', Confirmed='90049', Deaths='2540', Recovered='79763', Active='7746.0', Incidence_Rate='791.4837686015035', Case_Fatality_Ratio='2.820686515119547')]
# [CovidData(Combined_Key='Rio de Janeiro, Brazil', Country_Region='Brazil', Confirmed='185610', Deaths='14295', Recovered='165894', Active='5421.0', Incidence_Rate='1075.0687100443943', Case_Fatality_Ratio='7.701632455147891')]
# [CovidData(Combined_Key='Rondonia, Brazil', Country_Region='Brazil', Confirmed='46061', Deaths='981', Recovered='38312', Active='6768.0', Incidence_Rate='2591.737118260209', Case_Fatality_Ratio='2.129784416317492')]
# [CovidData(Combined_Key='Roraima, Brazil', Country_Region='Brazil', Confirmed='37579', Deaths='555', Recovered='9125', Active='27899.0', Incidence_Rate='6203.601750525372', Case_Fatality_Ratio='1.4768886878309695')]
# [CovidData(Combined_Key='Santa Catarina, Brazil', Country_Region='Brazil', Confirmed='112401', Deaths='1637', Recovered='99781', Active='10983.0', Incidence_Rate='1568.797290303635', Case_Fatality_Ratio='1.4563927367194245')]
# [CovidData(Combined_Key='Sao Paulo, Brazil', Country_Region='Brazil', Confirmed='655181', Deaths='25869', Recovered='453612', Active='175700.0', Incidence_Rate='1426.8174412758415', Case_Fatality_Ratio='3.948374571301671')]
# [CovidData(Combined_Key='Sergipe, Brazil', Country_Region='Brazil', Confirmed='65865', Deaths='1653', Recovered='47709', Active='16503.0', Incidence_Rate='2865.3201641278365', Case_Fatality_Ratio='2.509678888635846')]
# [CovidData(Combined_Key='Tocantins, Brazil', Country_Region='Brazil', Confirmed='33766', Deaths='482', Recovered='19845', Active='13439.0', Incidence_Rate='2146.7817347440914', Case_Fatality_Ratio='1.4274714209559909')]
# [CovidData(Combined_Key='Brunei', Country_Region='Brunei', Confirmed='142', Deaths='3', Recovered='138', Active='1.0', Incidence_Rate='32.45840409798781', Case_Fatality_Ratio='2.112676056338028')]
# [CovidData(Combined_Key='Bulgaria', Country_Region='Bulgaria', Confirmed='13893', Deaths='482', Recovered='8479', Active='4932.0', Incidence_Rate='199.9440162511181', Case_Fatality_Ratio='3.4693730655725905')]
# [CovidData(Combined_Key='Burkina Faso', Country_Region='Burkina Faso', Confirmed='1213', Deaths='54', Recovered='995', Active='164.0', Incidence_Rate='5.802917609381647', Case_Fatality_Ratio='4.451772464962902')]
# [CovidData(Combined_Key='Burma', Country_Region='Burma', Confirmed='361', Deaths='6', Recovered='318', Active='37.0', Incidence_Rate='0.6634834897555393', Case_Fatality_Ratio='1.6620498614958448')]
# [CovidData(Combined_Key='Burundi', Country_Region='Burundi', Confirmed='409', Deaths='1', Recovered='315', Active='93.0', Incidence_Rate='3.439639498868914', Case_Fatality_Ratio='0.2444987775061125')]
# [CovidData(Combined_Key='Cabo Verde', Country_Region='Cabo Verde', Confirmed='3000', Deaths='33', Recovered='2172', Active='795.0', Incidence_Rate='539.5799909350561', Case_Fatality_Ratio='1.1')]
# [CovidData(Combined_Key='Cambodia', Country_Region='Cambodia', Confirmed='272', Deaths='0', Recovered='223', Active='49.0', Incidence_Rate='1.6268943824353783', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Cameroon', Country_Region='Cameroon', Confirmed='18263', Deaths='401', Recovered='15320', Active='2542.0', Incidence_Rate='68.79791141851703', Case_Fatality_Ratio='2.195696216393802')]
# [CovidData(Combined_Key='Alberta, Canada', Country_Region='Canada', Confirmed='11893', Deaths='217', Recovered='10632', Active='1044.0', Incidence_Rate='269.49029105313986', Case_Fatality_Ratio='1.824602707474985')]
# [CovidData(Combined_Key='British Columbia, Canada', Country_Region='Canada', Confirmed='4111', Deaths='195', Recovered='3444', Active='472.0', Incidence_Rate='80.43566350226386', Case_Fatality_Ratio='4.7433714424714175')]
# [CovidData(Combined_Key='Grand Princess, Canada', Country_Region='Canada', Confirmed='13', Deaths='0', Recovered='13', Active='0.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Manitoba, Canada', Country_Region='Canada', Confirmed='578', Deaths='8', Recovered='368', Active='202.0', Incidence_Rate='41.95955476411543', Case_Fatality_Ratio='1.3840830449826989')]
# [CovidData(Combined_Key='New Brunswick, Canada', Country_Region='Canada', Confirmed='178', Deaths='2', Recovered='168', Active='8.0', Incidence_Rate='22.82071762182481', Case_Fatality_Ratio='1.1235955056179776')]
# [CovidData(Combined_Key='Newfoundland and Labrador, Canada', Country_Region='Canada', Confirmed='268', Deaths='3', Recovered='263', Active='2.0', Incidence_Rate='51.40352727935323', Case_Fatality_Ratio='1.1194029850746268')]
# [CovidData(Combined_Key='Northwest Territories,Canada', Country_Region='Canada', Confirmed='5', Deaths='0', Recovered='5', Active='0.0', Incidence_Rate='11.134865490824867', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Nova Scotia, Canada', Country_Region='Canada', Confirmed='1071', Deaths='64', Recovered='1007', Active='0.0', Incidence_Rate='109.57003735202672', Case_Fatality_Ratio='5.975723622782446')]
# [CovidData(Combined_Key='Ontario, Canada', Country_Region='Canada', Confirmed='42233', Deaths='2833', Recovered='38296', Active='1104.0', Incidence_Rate='287.068356635787', Case_Fatality_Ratio='6.708024530580353')]
# [CovidData(Combined_Key='Prince Edward Island, Canada', Country_Region='Canada', Confirmed='41', Deaths='0', Recovered='36', Active='5.0', Incidence_Rate='25.92344364496263', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Quebec, Canada', Country_Region='Canada', Confirmed='60813', Deaths='5709', Recovered='53270', Active='1834.0', Incidence_Rate='712.2900218490422', Case_Fatality_Ratio='9.387795372699916')]
# [CovidData(Combined_Key='Saskatchewan, Canada', Country_Region='Canada', Confirmed='1484', Deaths='20', Recovered='1314', Active='150.0', Incidence_Rate='125.5854023048814', Case_Fatality_Ratio='1.3477088948787062')]
# [CovidData(Combined_Key='Yukon, Canada', Country_Region='Canada', Confirmed='15', Deaths='0', Recovered='13', Active='2.0', Incidence_Rate='36.515896586980865', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Central African Republic', Country_Region='Central African Republic', Confirmed='4652', Deaths='61', Recovered='1728', Active='2863.0', Incidence_Rate='96.3194060827817', Case_Fatality_Ratio='1.3112639724849526')]
# [CovidData(Combined_Key='Chad', Country_Region='Chad', Confirmed='949', Deaths='76', Recovered='859', Active='14.0', Incidence_Rate='5.7774756254756605', Case_Fatality_Ratio='8.008429926238145')]
# [CovidData(Combined_Key='Antofagasta, Chile', Country_Region='Chile', Confirmed='16323', Deaths='388', Recovered='14811', Active='1124.0', Incidence_Rate='2686.7632099602656', Case_Fatality_Ratio='2.3770140292838327')]
# [CovidData(Combined_Key='Araucania, Chile', Country_Region='Chile', Confirmed='4490', Deaths='83', Recovered='4139', Active='268.0', Incidence_Rate='469.06471212589736', Case_Fatality_Ratio='1.8485523385300668')]
# [CovidData(Combined_Key='Arica y Parinacota, Chile', Country_Region='Chile', Confirmed='5451', Deaths='78', Recovered='4613', Active='760.0', Incidence_Rate='2411.2214024098944', Case_Fatality_Ratio='1.4309301045679692')]
# [CovidData(Combined_Key='Atacama, Chile', Country_Region='Chile', Confirmed='4108', Deaths='21', Recovered='3077', Active='1010.0', Incidence_Rate='1421.7287778946786', Case_Fatality_Ratio='0.5111976630963972')]
# [CovidData(Combined_Key='Aysen, Chile', Country_Region='Chile', Confirmed='95', Deaths='1', Recovered='82', Active='12.0', Incidence_Rate='92.09174276352779', Case_Fatality_Ratio='1.0526315789473684')]
# [CovidData(Combined_Key='Biobio, Chile', Country_Region='Chile', Confirmed='13260', Deaths='145', Recovered='11644', Active='1471.0', Incidence_Rate='851.7444381280893', Case_Fatality_Ratio='1.0935143288084463')]
# [CovidData(Combined_Key='Coquimbo, Chile', Country_Region='Chile', Confirmed='7631', Deaths='89', Recovered='6636', Active='906.0', Incidence_Rate='1007.2783815962808', Case_Fatality_Ratio='1.1662953741318307')]
# [CovidData(Combined_Key='Los Lagos, Chile', Country_Region='Chile', Confirmed='5149', Deaths='54', Recovered='4152', Active='943.0', Incidence_Rate='621.3286223856894', Case_Fatality_Ratio='1.0487473295785592')]
# [CovidData(Combined_Key='Los Rios, Chile', Country_Region='Chile', Confirmed='987', Deaths='15', Recovered='903', Active='69.0', Incidence_Rate='256.47222070642897', Case_Fatality_Ratio='1.5197568389057752')]
# [CovidData(Combined_Key='Magallanes, Chile', Country_Region='Chile', Confirmed='2128', Deaths='30', Recovered='1788', Active='310.0', Incidence_Rate='1277.8248155020324', Case_Fatality_Ratio='1.4097744360902256')]
# [CovidData(Combined_Key='Maule, Chile', Country_Region='Chile', Confirmed='10058', Deaths='203', Recovered='9050', Active='805.0', Incidence_Rate='962.5340925403128', Case_Fatality_Ratio='2.0182938954066416')]
# [CovidData(Combined_Key='Metropolitana, Chile', Country_Region='Chile', Confirmed='263567', Deaths='7992', Recovered='249956', Active='5619.0', Incidence_Rate='3705.5267061897353', Case_Fatality_Ratio='3.0322460702591747')]
# [CovidData(Combined_Key='Nuble, Chile', Country_Region='Chile', Confirmed='3879', Deaths='69', Recovered='3535', Active='275.0', Incidence_Rate='807.1009906181532', Case_Fatality_Ratio='1.7788089713843769')]
# [CovidData(Combined_Key='OHiggins, Chile', Country_Region='Chile', Confirmed='11843', Deaths='281', Recovered='10621', Active='941.0', Incidence_Rate='1294.946722723073', Case_Fatality_Ratio='2.372709617495567')]
# [CovidData(Combined_Key='Tarapaca, Chile', Country_Region='Chile', Confirmed='9617', Deaths='182', Recovered='8789', Active='646.0', Incidence_Rate='2909.3230234936077', Case_Fatality_Ratio='1.8924820630134136')]
# [CovidData(Combined_Key='Unknown, Chile', Country_Region='Chile', Confirmed='64', Deaths='1', Recovered='61', Active='2.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='1.5625')]
# [CovidData(Combined_Key='Valparaiso, Chile', Country_Region='Chile', Confirmed='19518', Deaths='573', Recovered='17562', Active='1383.0', Incidence_Rate='1074.8377390409835', Case_Fatality_Ratio='2.9357516138948663')]
# [CovidData(Combined_Key='Anhui, China', Country_Region='China', Confirmed='991', Deaths='6', Recovered='985', Active='0.0', Incidence_Rate='1.5670461733080334', Case_Fatality_Ratio='0.6054490413723511')]
# [CovidData(Combined_Key='Beijing, China', Country_Region='China', Confirmed='935', Deaths='9', Recovered='920', Active='6.0', Incidence_Rate='4.340761374187558', Case_Fatality_Ratio='0.9625668449197858')]
# [CovidData(Combined_Key='Chongqing, China', Country_Region='China', Confirmed='583', Deaths='6', Recovered='577', Active='0.0', Incidence_Rate='1.8794326241134751', Case_Fatality_Ratio='1.0291595197255574')]
# [CovidData(Combined_Key='Fujian, China', Country_Region='China', Confirmed='368', Deaths='1', Recovered='364', Active='3.0', Incidence_Rate='0.933773154021822', Case_Fatality_Ratio='0.2717391304347826')]
# [CovidData(Combined_Key='Gansu, China', Country_Region='China', Confirmed='169', Deaths='2', Recovered='165', Active='2.0', Incidence_Rate='0.6408797876374668', Case_Fatality_Ratio='1.183431952662722')]
# [CovidData(Combined_Key='Guangdong, China', Country_Region='China', Confirmed='1707', Deaths='8', Recovered='1678', Active='21.0', Incidence_Rate='1.5044949762030673', Case_Fatality_Ratio='0.4686584651435266')]
# [CovidData(Combined_Key='Guangxi, China', Country_Region='China', Confirmed='255', Deaths='2', Recovered='253', Active='0.0', Incidence_Rate='0.5176613885505481', Case_Fatality_Ratio='0.7843137254901961')]
# [CovidData(Combined_Key='Guizhou, China', Country_Region='China', Confirmed='147', Deaths='2', Recovered='145', Active='0.0', Incidence_Rate='0.4083333333333333', Case_Fatality_Ratio='1.3605442176870748')]
# [CovidData(Combined_Key='Hainan, China', Country_Region='China', Confirmed='171', Deaths='6', Recovered='165', Active='0.0', Incidence_Rate='1.8308351177730195', Case_Fatality_Ratio='3.5087719298245608')]
# [CovidData(Combined_Key='Hebei, China', Country_Region='China', Confirmed='351', Deaths='6', Recovered='343', Active='2.0', Incidence_Rate='0.4645314981471678', Case_Fatality_Ratio='1.7094017094017089')]
# [CovidData(Combined_Key='Heilongjiang, China', Country_Region='China', Confirmed='948', Deaths='13', Recovered='934', Active='1.0', Incidence_Rate='2.5125894513649616', Case_Fatality_Ratio='1.3713080168776368')]
# [CovidData(Combined_Key='Henan, China', Country_Region='China', Confirmed='1276', Deaths='22', Recovered='1254', Active='0.0', Incidence_Rate='1.3284747527329517', Case_Fatality_Ratio='1.7241379310344829')]
# [CovidData(Combined_Key='Hong Kong, China', Country_Region='China', Confirmed='4243', Deaths='63', Recovered='3189', Active='991.0', Incidence_Rate='56.596062311957816', Case_Fatality_Ratio='1.4847984916332784')]
# [CovidData(Combined_Key='Hubei, China', Country_Region='China', Confirmed='68139', Deaths='4512', Recovered='63623', Active='4.0', Incidence_Rate='115.1580192665202', Case_Fatality_Ratio='6.6217584643155885')]
# [CovidData(Combined_Key='Hunan, China', Country_Region='China', Confirmed='1019', Deaths='4', Recovered='1015', Active='0.0', Incidence_Rate='1.4770256558921582', Case_Fatality_Ratio='0.3925417075564279')]
# [CovidData(Combined_Key='Inner Mongolia, China', Country_Region='China', Confirmed='259', Deaths='1', Recovered='254', Active='4.0', Incidence_Rate='1.022099447513812', Case_Fatality_Ratio='0.3861003861003861')]
# [CovidData(Combined_Key='Jiangsu, China', Country_Region='China', Confirmed='659', Deaths='0', Recovered='656', Active='3.0', Incidence_Rate='0.8185318593963483', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Jiangxi, China', Country_Region='China', Confirmed='932', Deaths='1', Recovered='931', Active='0.0', Incidence_Rate='2.0051635111876074', Case_Fatality_Ratio='0.1072961373390558')]
# [CovidData(Combined_Key='Jilin, China', Country_Region='China', Confirmed='157', Deaths='2', Recovered='154', Active='1.0', Incidence_Rate='0.5806213017751479', Case_Fatality_Ratio='1.2738853503184713')]
# [CovidData(Combined_Key='Liaoning, China', Country_Region='China', Confirmed='261', Deaths='2', Recovered='202', Active='57.0', Incidence_Rate='0.5987611837577426', Case_Fatality_Ratio='0.7662835249042146')]
# [CovidData(Combined_Key='Macau, China', Country_Region='China', Confirmed='46', Deaths='0', Recovered='46', Active='0.0', Incidence_Rate='7.084094360136879', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Ningxia, China', Country_Region='China', Confirmed='75', Deaths='0', Recovered='75', Active='0.0', Incidence_Rate='1.0901162790697674', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Qinghai, China', Country_Region='China', Confirmed='18', Deaths='0', Recovered='18', Active='0.0', Incidence_Rate='0.29850746268656714', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Shaanxi, China', Country_Region='China', Confirmed='341', Deaths='3', Recovered='324', Active='14.0', Incidence_Rate='0.8825051759834368', Case_Fatality_Ratio='0.8797653958944281')]
# [CovidData(Combined_Key='Shandong, China', Country_Region='China', Confirmed='821', Deaths='7', Recovered='789', Active='25.0', Incidence_Rate='0.8171593510500647', Case_Fatality_Ratio='0.8526187576126675')]
# [CovidData(Combined_Key='Shanghai, China', Country_Region='China', Confirmed='800', Deaths='7', Recovered='737', Active='56.0', Incidence_Rate='3.3003300330033003', Case_Fatality_Ratio='0.875')]
# [CovidData(Combined_Key='Shanxi, China', Country_Region='China', Confirmed='201', Deaths='0', Recovered='201', Active='0.0', Incidence_Rate='0.5406132329209252', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Sichuan, China', Country_Region='China', Confirmed='618', Deaths='3', Recovered='602', Active='13.0', Incidence_Rate='0.7409183551132957', Case_Fatality_Ratio='0.4854368932038835')]
# [CovidData(Combined_Key='Tianjin, China', Country_Region='China', Confirmed='205', Deaths='3', Recovered='202', Active='0.0', Incidence_Rate='1.314102564102564', Case_Fatality_Ratio='1.4634146341463414')]
# [CovidData(Combined_Key='Tibet, China', Country_Region='China', Confirmed='1', Deaths='0', Recovered='1', Active='0.0', Incidence_Rate='0.02906976744186046', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Xinjiang, China', Country_Region='China', Confirmed='883', Deaths='3', Recovered='375', Active='505.0', Incidence_Rate='3.5504624045034183', Case_Fatality_Ratio='0.3397508493771235')]
# [CovidData(Combined_Key='Yunnan, China', Country_Region='China', Confirmed='191', Deaths='2', Recovered='188', Active='1.0', Incidence_Rate='0.39544513457556935', Case_Fatality_Ratio='1.0471204188481675')]
# [CovidData(Combined_Key='Zhejiang, China', Country_Region='China', Confirmed='1275', Deaths='1', Recovered='1268', Active='6.0', Incidence_Rate='2.22241589681018', Case_Fatality_Ratio='0.0784313725490196')]
# [CovidData(Combined_Key='Amazonas, Colombia', Country_Region='Colombia', Confirmed='2641', Deaths='105', Recovered='2388', Active='148.0', Incidence_Rate='3448.2758620689656', Case_Fatality_Ratio='3.975766755017039')]
# [CovidData(Combined_Key='Antioquia, Colombia', Country_Region='Colombia', Confirmed='55820', Deaths='989', Recovered='25896', Active='28935.0', Incidence_Rate='871.2207172603153', Case_Fatality_Ratio='1.7717663919742028')]
# [CovidData(Combined_Key='Arauca, Colombia', Country_Region='Colombia', Confirmed='511', Deaths='9', Recovered='197', Active='305.0', Incidence_Rate='194.9087247400581', Case_Fatality_Ratio='1.761252446183953')]
# [CovidData(Combined_Key='Atlantico, Colombia', Country_Region='Colombia', Confirmed='59383', Deaths='2726', Recovered='46990', Active='9667.0', Incidence_Rate='2342.0470065868217', Case_Fatality_Ratio='4.590539379957226')]
# [CovidData(Combined_Key='Bolivar, Colombia', Country_Region='Colombia', Confirmed='20925', Deaths='635', Recovered='16679', Active='3611.0', Incidence_Rate='1010.8158503654396', Case_Fatality_Ratio='3.034647550776583')]
# [CovidData(Combined_Key='Boyaca, Colombia', Country_Region='Colombia', Confirmed='1763', Deaths='43', Recovered='765', Active='955.0', Incidence_Rate='144.8196777330915', Case_Fatality_Ratio='2.4390243902439024')]
# [CovidData(Combined_Key='Caldas, Colombia', Country_Region='Colombia', Confirmed='1455', Deaths='22', Recovered='511', Active='922.0', Incidence_Rate='145.75434132561318', Case_Fatality_Ratio='1.5120274914089349')]
# [CovidData(Combined_Key='Capital District, Colombia', Country_Region='Colombia', Confirmed='146109', Deaths='3998', Recovered='75551', Active='66560.0', Incidence_Rate='1971.0988070797614', Case_Fatality_Ratio='2.736313300344264')]
# [CovidData(Combined_Key='Caqueta, Colombia', Country_Region='Colombia', Confirmed='2944', Deaths='82', Recovered='958', Active='1904.0', Incidence_Rate='733.2704009325287', Case_Fatality_Ratio='2.785326086956522')]
# [CovidData(Combined_Key='Casanare, Colombia', Country_Region='Colombia', Confirmed='535', Deaths='9', Recovered='207', Active='319.0', Incidence_Rate='127.22827844681619', Case_Fatality_Ratio='1.6822429906542056')]
# [CovidData(Combined_Key='Cauca, Colombia', Country_Region='Colombia', Confirmed='2810', Deaths='101', Recovered='1473', Active='1236.0', Incidence_Rate='191.8759320663604', Case_Fatality_Ratio='3.5943060498220643')]
# [CovidData(Combined_Key='Cesar, Colombia', Country_Region='Colombia', Confirmed='4858', Deaths='104', Recovered='2327', Active='2427.0', Incidence_Rate='404.63978063826136', Case_Fatality_Ratio='2.140798682585426')]
# [CovidData(Combined_Key='Choco, Colombia', Country_Region='Colombia', Confirmed='3404', Deaths='121', Recovered='2658', Active='625.0', Incidence_Rate='636.4686832726908', Case_Fatality_Ratio='3.554641598119859')]
# [CovidData(Combined_Key='Cordoba, Colombia', Country_Region='Colombia', Confirmed='11623', Deaths='903', Recovered='5105', Active='5615.0', Incidence_Rate='651.2276282326759', Case_Fatality_Ratio='7.769078551148585')]
# [CovidData(Combined_Key='Cundinamarca, Colombia', Country_Region='Colombia', Confirmed='13031', Deaths='353', Recovered='7186', Active='5492.0', Incidence_Rate='446.41083088391474', Case_Fatality_Ratio='2.7089248714603635')]
# [CovidData(Combined_Key='Guainia, Colombia', Country_Region='Colombia', Confirmed='20', Deaths='1', Recovered='13', Active='6.0', Incidence_Rate='41.56794280251071', Case_Fatality_Ratio='5.0')]
# [CovidData(Combined_Key='Guaviare, Colombia', Country_Region='Colombia', Confirmed='176', Deaths='0', Recovered='69', Active='107.0', Incidence_Rate='212.6451363466116', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Huila, Colombia', Country_Region='Colombia', Confirmed='1998', Deaths='54', Recovered='691', Active='1253.0', Incidence_Rate='181.5726481434696', Case_Fatality_Ratio='2.7027027027027017')]
# [CovidData(Combined_Key='La Guajira, Colombia', Country_Region='Colombia', Confirmed='3062', Deaths='155', Recovered='1797', Active='1110.0', Incidence_Rate='347.7332606523121', Case_Fatality_Ratio='5.062050947093403')]
# [CovidData(Combined_Key='Magdalena, Colombia', Country_Region='Colombia', Confirmed='9117', Deaths='458', Recovered='5278', Active='3381.0', Incidence_Rate='679.4877719031767', Case_Fatality_Ratio='5.023582318745201')]
# [CovidData(Combined_Key='Meta, Colombia', Country_Region='Colombia', Confirmed='4583', Deaths='70', Recovered='2462', Active='2051.0', Incidence_Rate='440.79090372234117', Case_Fatality_Ratio='1.5273838097316168')]
# [CovidData(Combined_Key='Narino, Colombia', Country_Region='Colombia', Confirmed='10404', Deaths='362', Recovered='6363', Active='3679.0', Incidence_Rate='638.0504749195384', Case_Fatality_Ratio='3.479430988081507')]
# [CovidData(Combined_Key='Norte de Santander, Colombia', Country_Region='Colombia', Confirmed='5492', Deaths='298', Recovered='2200', Active='2994.0', Incidence_Rate='368.17325863501037', Case_Fatality_Ratio='5.426074289876183')]
# [CovidData(Combined_Key='Putumayo, Colombia', Country_Region='Colombia', Confirmed='1638', Deaths='75', Recovered='604', Active='959.0', Incidence_Rate='470.44361856730103', Case_Fatality_Ratio='4.5787545787545785')]
# [CovidData(Combined_Key='Quindio, Colombia', Country_Region='Colombia', Confirmed='558', Deaths='13', Recovered='269', Active='276.0', Incidence_Rate='103.35170697012802', Case_Fatality_Ratio='2.3297491039426523')]
# [CovidData(Combined_Key='Risaralda, Colombia', Country_Region='Colombia', Confirmed='2982', Deaths='55', Recovered='1167', Active='1760.0', Incidence_Rate='316.09040058257307', Case_Fatality_Ratio='1.844399731723676')]
# [CovidData(Combined_Key='San Andres y Providencia, Colombia', Country_Region='Colombia', Confirmed='59', Deaths='0', Recovered='34', Active='25.0', Incidence_Rate='96.27937336814621', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Santander, Colombia', Country_Region='Colombia', Confirmed='8060', Deaths='304', Recovered='2687', Active='5069.0', Incidence_Rate='368.9062387720457', Case_Fatality_Ratio='3.771712158808933')]
# [CovidData(Combined_Key='Sucre, Colombia', Country_Region='Colombia', Confirmed='7878', Deaths='402', Recovered='4924', Active='2552.0', Incidence_Rate='870.6290344505188', Case_Fatality_Ratio='5.102817974105103')]
# [CovidData(Combined_Key='Tolima, Colombia', Country_Region='Colombia', Confirmed='3952', Deaths='91', Recovered='2026', Active='1835.0', Incidence_Rate='297.1010842836384', Case_Fatality_Ratio='2.3026315789473686')]
# [CovidData(Combined_Key='Valle del Cauca, Colombia', Country_Region='Colombia', Confirmed='34585', Deaths='1298', Recovered='20248', Active='13039.0', Incidence_Rate='772.6961768016432', Case_Fatality_Ratio='3.7530721411016335')]
# [CovidData(Combined_Key='Vaupes, Colombia', Country_Region='Colombia', Confirmed='137', Deaths='1', Recovered='60', Active='76.0', Incidence_Rate='335.8090055641346', Case_Fatality_Ratio='0.7299270072992701')]
# [CovidData(Combined_Key='Vichada, Colombia', Country_Region='Colombia', Confirmed='6', Deaths='0', Recovered='2', Active='4.0', Incidence_Rate='5.565449688334818', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Comoros', Country_Region='Comoros', Confirmed='399', Deaths='7', Recovered='379', Active='13.0', Incidence_Rate='45.883428492574126', Case_Fatality_Ratio='1.7543859649122806')]
# [CovidData(Combined_Key='Congo (Brazzaville)', Country_Region='Congo (Brazzaville)', Confirmed='3745', Deaths='60', Recovered='1625', Active='2060.0', Incidence_Rate='67.86766150328775', Case_Fatality_Ratio='1.6021361815754338')]
# [CovidData(Combined_Key='Congo (Kinshasa)', Country_Region='Congo (Kinshasa)', Confirmed='9538', Deaths='225', Recovered='8421', Active='892.0', Incidence_Rate='10.649676729051725', Case_Fatality_Ratio='2.358985112182848')]
# [CovidData(Combined_Key='Costa Rica', Country_Region='Costa Rica', Confirmed='25057', Deaths='263', Recovered='8189', Active='16605.0', Incidence_Rate='491.8814145109434', Case_Fatality_Ratio='1.0496068962764895')]
# [CovidData(Combined_Key="Cote d'Ivoire", Country_Region="Cote d'Ivoire", Confirmed='16847', Deaths='105', Recovered='13321', Active='3421.0', Incidence_Rate='63.86695111791806', Case_Fatality_Ratio='0.6232563661185968')]
# [CovidData(Combined_Key='Croatia', Country_Region='Croatia', Confirmed='5870', Deaths='160', Recovered='5024', Active='686.0', Incidence_Rate='142.9870108358334', Case_Fatality_Ratio='2.7257240204429305')]
# [CovidData(Combined_Key='Cuba', Country_Region='Cuba', Confirmed='3128', Deaths='88', Recovered='2504', Active='536.0', Incidence_Rate='27.616368383990412', Case_Fatality_Ratio='2.8132992327365733')]
# [CovidData(Combined_Key='Cyprus', Country_Region='Cyprus', Confirmed='1291', Deaths='20', Recovered='870', Active='401.0', Incidence_Rate='106.92742270124675', Case_Fatality_Ratio='1.5491866769945783')]
# [CovidData(Combined_Key='Czechia', Country_Region='Czechia', Confirmed='19075', Deaths='391', Recovered='13407', Active='5277.0', Incidence_Rate='178.1215058536843', Case_Fatality_Ratio='2.0498034076015728')]
# [CovidData(Combined_Key='Faroe Islands, Denmark', Country_Region='Denmark', Confirmed='339', Deaths='0', Recovered='225', Active='114.0', Incidence_Rate='693.7480814488898', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Greenland, Denmark', Country_Region='Denmark', Confirmed='14', Deaths='0', Recovered='14', Active='0.0', Incidence_Rate='24.660043683505954', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Denmark', Country_Region='Denmark', Confirmed='15070', Deaths='621', Recovered='13066', Active='1383.0', Incidence_Rate='260.17734530367807', Case_Fatality_Ratio='4.120769741207697')]
# [CovidData(Combined_Key='Diamond Princess', Country_Region='Diamond Princess', Confirmed='712', Deaths='13', Recovered='651', Active='48.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='1.8258426966292127')]
# [CovidData(Combined_Key='Djibouti', Country_Region='Djibouti', Confirmed='5358', Deaths='59', Recovered='5150', Active='149.0', Incidence_Rate='542.3065945210637', Case_Fatality_Ratio='1.101157148189623')]
# [CovidData(Combined_Key='Dominica', Country_Region='Dominica', Confirmed='18', Deaths='0', Recovered='18', Active='0.0', Incidence_Rate='25.003125390673837', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Dominican Republic', Country_Region='Dominican Republic', Confirmed='82224', Deaths='1371', Recovered='47095', Active='33758.0', Incidence_Rate='757.9713094806149', Case_Fatality_Ratio='1.6673963806187977')]
# [CovidData(Combined_Key='Ecuador', Country_Region='Ecuador', Confirmed='97110', Deaths='5984', Recovered='78887', Active='12239.0', Incidence_Rate='550.414723976453', Case_Fatality_Ratio='6.162084234373393')]
# [CovidData(Combined_Key='Egypt', Country_Region='Egypt', Confirmed='95963', Deaths='5085', Recovered='55901', Active='34977.0', Incidence_Rate='93.7739383694846', Case_Fatality_Ratio='5.298917291039254')]
# [CovidData(Combined_Key='El Salvador', Country_Region='El Salvador', Confirmed='21644', Deaths='577', Recovered='10056', Active='11011.0', Incidence_Rate='333.693019997376', Case_Fatality_Ratio='2.6658658288671218')]
# [CovidData(Combined_Key='Equatorial Guinea', Country_Region='Equatorial Guinea', Confirmed='4821', Deaths='83', Recovered='2182', Active='2556.0', Incidence_Rate='343.6244863630046', Case_Fatality_Ratio='1.7216345156606514')]
# [CovidData(Combined_Key='Eritrea', Country_Region='Eritrea', Confirmed='285', Deaths='0', Recovered='248', Active='37.0', Incidence_Rate='8.03625733731443', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Estonia', Country_Region='Estonia', Confirmed='2174', Deaths='63', Recovered='1975', Active='136.0', Incidence_Rate='163.88511758794883', Case_Fatality_Ratio='2.8978840846366145')]
# [CovidData(Combined_Key='Eswatini', Country_Region='Eswatini', Confirmed='3525', Deaths='63', Recovered='1910', Active='1552.0', Incidence_Rate='303.83635417061726', Case_Fatality_Ratio='1.7872340425531914')]
# [CovidData(Combined_Key='Ethiopia', Country_Region='Ethiopia', Confirmed='25118', Deaths='463', Recovered='11034', Active='13621.0', Incidence_Rate='21.848657935443782', Case_Fatality_Ratio='1.8432996257663827')]
# [CovidData(Combined_Key='Fiji', Country_Region='Fiji', Confirmed='27', Deaths='1', Recovered='18', Active='8.0', Incidence_Rate='3.0119003529501005', Case_Fatality_Ratio='3.703703703703704')]
# [CovidData(Combined_Key='Finland', Country_Region='Finland', Confirmed='7642', Deaths='333', Recovered='7050', Active='259.0', Incidence_Rate='137.9243628713824', Case_Fatality_Ratio='4.357498037163047')]
# [CovidData(Combined_Key='French Guiana, France', Country_Region='France', Confirmed='8423', Deaths='50', Recovered='7713', Active='660.0', Incidence_Rate='2820.056113190617', Case_Fatality_Ratio='0.5936127270568681')]
# [CovidData(Combined_Key='French Polynesia, France', Country_Region='France', Confirmed='139', Deaths='0', Recovered='64', Active='75.0', Incidence_Rate='49.4830974283029', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Guadeloupe, France', Country_Region='France', Confirmed='367', Deaths='14', Recovered='289', Active='64.0', Incidence_Rate='91.72087862103784', Case_Fatality_Ratio='3.8147138964577656')]
# [CovidData(Combined_Key='Martinique, France', Country_Region='France', Confirmed='336', Deaths='16', Recovered='98', Active='222.0', Incidence_Rate='89.53672737931862', Case_Fatality_Ratio='4.761904761904762')]
# [CovidData(Combined_Key='Mayotte, France', Country_Region='France', Confirmed='3091', Deaths='39', Recovered='2835', Active='217.0', Incidence_Rate='1133.0105236920529', Case_Fatality_Ratio='1.2617275962471692')]
# [CovidData(Combined_Key='New Caledonia, France', Country_Region='France', Confirmed='23', Deaths='0', Recovered='22', Active='1.0', Incidence_Rate='8.056295995320342', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Reunion, France', Country_Region='France', Confirmed='734', Deaths='5', Recovered='631', Active='98.0', Incidence_Rate='81.98296005397027', Case_Fatality_Ratio='0.6811989100817438')]
# [CovidData(Combined_Key='Saint Barthelemy, France', Country_Region='France', Confirmed='13', Deaths='0', Recovered='6', Active='7.0', Incidence_Rate='131.51239251390996', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Saint Pierre and Miquelon, France', Country_Region='France', Confirmed='4', Deaths='0', Recovered='1', Active='3.0', Incidence_Rate='69.02502157031924', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='St Martin, France', Country_Region='France', Confirmed='84', Deaths='4', Recovered='44', Active='36.0', Incidence_Rate='217.28446157427769', Case_Fatality_Ratio='4.761904761904762')]
# [CovidData(Combined_Key='France', Country_Region='France', Confirmed='230874', Deaths='30247', Recovered='71906', Active='128721.0', Incidence_Rate='353.7024329256253', Case_Fatality_Ratio='13.101085440543327')]
# [CovidData(Combined_Key='Gabon', Country_Region='Gabon', Confirmed='8077', Deaths='51', Recovered='5920', Active='2106.0', Incidence_Rate='362.8925007907525', Case_Fatality_Ratio='0.6314225578804011')]
# [CovidData(Combined_Key='Gambia', Country_Region='Gambia', Confirmed='1477', Deaths='33', Recovered='247', Active='1197.0', Incidence_Rate='61.11730881909938', Case_Fatality_Ratio='2.2342586323628977')]
# [CovidData(Combined_Key='Georgia', Country_Region='Georgia', Confirmed='1278', Deaths='17', Recovered='1058', Active='203.0', Incidence_Rate='32.036699317528054', Case_Fatality_Ratio='1.330203442879499')]
# [CovidData(Combined_Key='Baden-Wurttemberg, Germany', Country_Region='Germany', Confirmed='38165', Deaths='1859', Recovered='35200', Active='1106.0', Incidence_Rate='344.77515898818865', Case_Fatality_Ratio='4.870955063539894')]
# [CovidData(Combined_Key='Bayern, Germany', Country_Region='Germany', Confirmed='52203', Deaths='2627', Recovered='48200', Active='1376.0', Incidence_Rate='399.2055806650612', Case_Fatality_Ratio='5.032277838438404')]
# [CovidData(Combined_Key='Berlin, Germany', Country_Region='Germany', Confirmed='9975', Deaths='224', Recovered='9088', Active='663.0', Incidence_Rate='273.67561579071264', Case_Fatality_Ratio='2.245614035087719')]
# [CovidData(Combined_Key='Brandenburg, Germany', Country_Region='Germany', Confirmed='3667', Deaths='175', Recovered='3400', Active='92.0', Incidence_Rate='145.98412288304112', Case_Fatality_Ratio='4.772293427870193')]
# [CovidData(Combined_Key='Bremen, Germany', Country_Region='Germany', Confirmed='1825', Deaths='56', Recovered='1709', Active='60.0', Incidence_Rate='267.2089911066991', Case_Fatality_Ratio='3.068493150684932')]
# [CovidData(Combined_Key='Hamburg, Germany', Country_Region='Germany', Confirmed='5773', Deaths='262', Recovered='5100', Active='411.0', Incidence_Rate='313.54909001243226', Case_Fatality_Ratio='4.53836826606617')]
# [CovidData(Combined_Key='Hessen, Germany', Country_Region='Germany', Confirmed='12876', Deaths='526', Recovered='11500', Active='850.0', Incidence_Rate='205.49620966741887', Case_Fatality_Ratio='4.085119602360981')]
# [CovidData(Combined_Key='Mecklenburg-Vorpommern, Germany', Country_Region='Germany', Confirmed='954', Deaths='20', Recovered='848', Active='86.0', Incidence_Rate='59.26662214422166', Case_Fatality_Ratio='2.0964360587002098')]
# [CovidData(Combined_Key='Niedersachsen, Germany', Country_Region='Germany', Confirmed='15122', Deaths='655', Recovered='13700', Active='767.0', Incidence_Rate='189.4406327482497', Case_Fatality_Ratio='4.33143764052374')]
# [CovidData(Combined_Key='Nordrhein-Westfalen, Germany', Country_Region='Germany', Confirmed='52588', Deaths='1765', Recovered='46600', Active='4223.0', Incidence_Rate='293.2527934659521', Case_Fatality_Ratio='3.356278999011181')]
# [CovidData(Combined_Key='Rheinland-Pfalz, Germany', Country_Region='Germany', Confirmed='7937', Deaths='239', Recovered='7250', Active='448.0', Incidence_Rate='194.3036257932984', Case_Fatality_Ratio='3.0112133047751035')]
# [CovidData(Combined_Key='Saarland, Germany', Country_Region='Germany', Confirmed='2952', Deaths='174', Recovered='2694', Active='84.0', Incidence_Rate='298.0285893414396', Case_Fatality_Ratio='5.894308943089431')]
# [CovidData(Combined_Key='Sachsen, Germany', Country_Region='Germany', Confirmed='5682', Deaths='225', Recovered='5305', Active='152.0', Incidence_Rate='139.33515892962544', Case_Fatality_Ratio='3.9598732840549102')]
# [CovidData(Combined_Key='Sachsen-Anhalt, Germany', Country_Region='Germany', Confirmed='2093', Deaths='64', Recovered='1937', Active='92.0', Incidence_Rate='94.7778878161282', Case_Fatality_Ratio='3.057811753463928')]
# [CovidData(Combined_Key='Schleswig-Holstein, Germany', Country_Region='Germany', Confirmed='3714', Deaths='158', Recovered='3260', Active='296.0', Incidence_Rate='128.21433404494476', Case_Fatality_Ratio='4.2541733979536875')]
# [CovidData(Combined_Key='Thuringen, Germany', Country_Region='Germany', Confirmed='3453', Deaths='184', Recovered='3200', Active='69.0', Incidence_Rate='161.11835643411902', Case_Fatality_Ratio='5.328699681436431')]
# [CovidData(Combined_Key='Unknown, Germany', Country_Region='Germany', Confirmed='1880', Deaths='0', Recovered='0', Active='1880.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Ghana', Country_Region='Ghana', Confirmed='41572', Deaths='223', Recovered='39320', Active='2029.0', Incidence_Rate='133.78841303906015', Case_Fatality_Ratio='0.5364187433849706')]
# [CovidData(Combined_Key='Greece', Country_Region='Greece', Confirmed='6177', Deaths='216', Recovered='1347', Active='4614.0', Incidence_Rate='59.262849590369655', Case_Fatality_Ratio='3.4968431277319088')]
# [CovidData(Combined_Key='Grenada', Country_Region='Grenada', Confirmed='24', Deaths='0', Recovered='23', Active='1.0', Incidence_Rate='21.329730978768033', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Guatemala', Country_Region='Guatemala', Confirmed='59089', Deaths='2267', Recovered='47394', Active='9428.0', Incidence_Rate='329.81931300304365', Case_Fatality_Ratio='3.836585489685052')]
# [CovidData(Combined_Key='Guinea', Country_Region='Guinea', Confirmed='8116', Deaths='50', Recovered='7060', Active='1006.0', Incidence_Rate='61.79950158351705', Case_Fatality_Ratio='0.6160670280926565')]
# [CovidData(Combined_Key='Guinea-Bissau', Country_Region='Guinea-Bissau', Confirmed='2088', Deaths='29', Recovered='1015', Active='1044.0', Incidence_Rate='106.0976687984439', Case_Fatality_Ratio='1.3888888888888888')]
# [CovidData(Combined_Key='Guyana', Country_Region='Guyana', Confirmed='623', Deaths='22', Recovered='191', Active='410.0', Incidence_Rate='79.20575570300511', Case_Fatality_Ratio='3.531300160513644')]
# ...
# [CovidData(Combined_Key='Campbell, Wyoming, US', Country_Region='US', Confirmed='132', Deaths='0', Recovered='0', Active='132.0', Incidence_Rate='284.84495371269503', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Carbon, Wyoming, US', Country_Region='US', Confirmed='105', Deaths='0', Recovered='0', Active='105.0', Incidence_Rate='709.4594594594595', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Converse, Wyoming, US', Country_Region='US', Confirmed='31', Deaths='0', Recovered='0', Active='31.0', Incidence_Rate='224.2801331211113', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Crook, Wyoming, US', Country_Region='US', Confirmed='10', Deaths='0', Recovered='0', Active='10.0', Incidence_Rate='131.85654008438817', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Fremont, Wyoming, US', Country_Region='US', Confirmed='500', Deaths='0', Recovered='0', Active='500.0', Incidence_Rate='1273.528437890018', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Goshen, Wyoming, US', Country_Region='US', Confirmed='34', Deaths='0', Recovered='0', Active='34.0', Incidence_Rate='257.36128983422907', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Hot Springs, Wyoming, US', Country_Region='US', Confirmed='23', Deaths='0', Recovered='0', Active='23.0', Incidence_Rate='521.1874008610922', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Johnson, Wyoming, US', Country_Region='US', Confirmed='24', Deaths='1', Recovered='0', Active='23.0', Incidence_Rate='284.1918294849023', Case_Fatality_Ratio='4.166666666666667')]
# [CovidData(Combined_Key='Laramie, Wyoming, US', Country_Region='US', Confirmed='504', Deaths='0', Recovered='0', Active='504.0', Incidence_Rate='506.5326633165829', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Lincoln, Wyoming, US', Country_Region='US', Confirmed='100', Deaths='0', Recovered='0', Active='100.0', Incidence_Rate='504.2864346949067', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Natrona, Wyoming, US', Country_Region='US', Confirmed='238', Deaths='0', Recovered='0', Active='238.0', Incidence_Rate='298.0290014776228', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Niobrara, Wyoming, US', Country_Region='US', Confirmed='2', Deaths='0', Recovered='0', Active='2.0', Incidence_Rate='84.88964346349746', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Park, Wyoming, US', Country_Region='US', Confirmed='135', Deaths='0', Recovered='0', Active='135.0', Incidence_Rate='462.4237857093924', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Platte, Wyoming, US', Country_Region='US', Confirmed='5', Deaths='0', Recovered='0', Active='5.0', Incidence_Rate='59.57345406886692', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Sheridan, Wyoming, US', Country_Region='US', Confirmed='73', Deaths='0', Recovered='0', Active='73.0', Incidence_Rate='239.46203050680663', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Sublette, Wyoming, US', Country_Region='US', Confirmed='40', Deaths='0', Recovered='0', Active='40.0', Incidence_Rate='406.87620791374223', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Sweetwater, Wyoming, US', Country_Region='US', Confirmed='266', Deaths='0', Recovered='0', Active='266.0', Incidence_Rate='628.2030087617787', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Teton, Wyoming, US', Country_Region='US', Confirmed='373', Deaths='0', Recovered='0', Active='373.0', Incidence_Rate='1589.669280600068', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Uinta, Wyoming, US', Country_Region='US', Confirmed='278', Deaths='0', Recovered='0', Active='278.0', Incidence_Rate='1374.4685058835162', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Unassigned, Wyoming, US', Country_Region='US', Confirmed='0', Deaths='28', Recovered='0', Active='-28.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='-99.0')]
# [CovidData(Combined_Key='Washakie, Wyoming, US', Country_Region='US', Confirmed='82', Deaths='0', Recovered='0', Active='82.0', Incidence_Rate='1050.6085842408713', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Weston, Wyoming, US', Country_Region='US', Confirmed='5', Deaths='0', Recovered='0', Active='5.0', Incidence_Rate='72.18131947452', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Uganda', Country_Region='Uganda', Confirmed='1332', Deaths='9', Recovered='1139', Active='184.0', Incidence_Rate='2.912048271791172', Case_Fatality_Ratio='0.6756756756756757')]
# [CovidData(Combined_Key='Cherkasy Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1049', Deaths='37', Recovered='789', Active='223.0', Incidence_Rate='86.95644965685774', Case_Fatality_Ratio='3.5271687321258343')]
# [CovidData(Combined_Key='Chernihiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1080', Deaths='18', Recovered='564', Active='498.0', Incidence_Rate='107.38308418137798', Case_Fatality_Ratio='1.6666666666666667')]
# [CovidData(Combined_Key='Chernivtsi Oblast, Ukraine', Country_Region='Ukraine', Confirmed='6980', Deaths='232', Recovered='5312', Active='1436.0', Incidence_Rate='771.8045852711379', Case_Fatality_Ratio='3.32378223495702')]
# [CovidData(Combined_Key='Crimea Republic*, Ukraine', Country_Region='Ukraine', Confirmed='1557', Deaths='18', Recovered='1077', Active='462.0', Incidence_Rate='81.35939690583473', Case_Fatality_Ratio='1.1560693641618498')]
# [CovidData(Combined_Key='Dnipropetrovsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1602', Deaths='36', Recovered='1152', Active='414.0', Incidence_Rate='49.96137505430415', Case_Fatality_Ratio='2.247191011235955')]
# [CovidData(Combined_Key='Donetsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1011', Deaths='13', Recovered='780', Active='218.0', Incidence_Rate='24.268459572130972', Case_Fatality_Ratio='1.2858555885262115')]
# [CovidData(Combined_Key='Ivano-Frankivsk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='6039', Deaths='160', Recovered='2372', Active='3507.0', Incidence_Rate='439.7590536915293', Case_Fatality_Ratio='2.649445272396092')]
# [CovidData(Combined_Key='Kharkiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='5169', Deaths='150', Recovered='2552', Active='2467.0', Incidence_Rate='193.19045686235376', Case_Fatality_Ratio='2.9019152640742885')]
# [CovidData(Combined_Key='Kherson Oblast, Ukraine', Country_Region='Ukraine', Confirmed='276', Deaths='5', Recovered='213', Active='58.0', Incidence_Rate='26.59882040013877', Case_Fatality_Ratio='1.8115942028985508')]
# [CovidData(Combined_Key='Khmelnytskyi Oblast, Ukraine', Country_Region='Ukraine', Confirmed='1413', Deaths='31', Recovered='1045', Active='337.0', Incidence_Rate='111.72565934348326', Case_Fatality_Ratio='2.193913658881812')]
# [CovidData(Combined_Key='Kiev, Ukraine', Country_Region='Ukraine', Confirmed='9869', Deaths='147', Recovered='3278', Active='6444.0', Incidence_Rate='334.45167412227187', Case_Fatality_Ratio='1.4895126152599047')]
# [CovidData(Combined_Key='Kiev Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4307', Deaths='71', Recovered='3021', Active='1215.0', Incidence_Rate='243.61686482572938', Case_Fatality_Ratio='1.6484792198746228')]
# [CovidData(Combined_Key='Kirovohrad Oblast, Ukraine', Country_Region='Ukraine', Confirmed='728', Deaths='39', Recovered='655', Active='34.0', Incidence_Rate='76.99230817228933', Case_Fatality_Ratio='5.357142857142857')]
# [CovidData(Combined_Key='Luhansk Oblast, Ukraine', Country_Region='Ukraine', Confirmed='160', Deaths='1', Recovered='117', Active='42.0', Incidence_Rate='7.435521250952095', Case_Fatality_Ratio='0.625')]
# [CovidData(Combined_Key='Lviv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='11308', Deaths='310', Recovered='3040', Active='7958.0', Incidence_Rate='448.3705726478884', Case_Fatality_Ratio='2.7414220021223907')]
# [CovidData(Combined_Key='Mykolaiv Oblast, Ukraine', Country_Region='Ukraine', Confirmed='744', Deaths='18', Recovered='493', Active='233.0', Incidence_Rate='29.50015087106729', Case_Fatality_Ratio='2.419354838709677')]
# [CovidData(Combined_Key='Odessa Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4458', Deaths='73', Recovered='1463', Active='2922.0', Incidence_Rate='187.28668726904246', Case_Fatality_Ratio='1.6375056078959174')]
# [CovidData(Combined_Key='Poltava Oblast, Ukraine', Country_Region='Ukraine', Confirmed='514', Deaths='15', Recovered='372', Active='127.0', Incidence_Rate='36.70277677214074', Case_Fatality_Ratio='2.9182879377431905')]
# [CovidData(Combined_Key='Rivne Oblast, Ukraine', Country_Region='Ukraine', Confirmed='7114', Deaths='106', Recovered='5407', Active='1601.0', Incidence_Rate='614.7061136212619', Case_Fatality_Ratio='1.490019679505201')]
# [CovidData(Combined_Key='Sevastopol*, Ukraine', Country_Region='Ukraine', Confirmed='399', Deaths='11', Recovered='321', Active='67.0', Incidence_Rate='90.02484144120972', Case_Fatality_Ratio='2.7568922305764407')]
# [CovidData(Combined_Key='Sumy Oblast, Ukraine', Country_Region='Ukraine', Confirmed='716', Deaths='10', Recovered='426', Active='280.0', Incidence_Rate='66.20936585113249', Case_Fatality_Ratio='1.3966480446927374')]
# [CovidData(Combined_Key='Ternopil Oblast, Ukraine', Country_Region='Ukraine', Confirmed='3413', Deaths='44', Recovered='2255', Active='1114.0', Incidence_Rate='326.3283802428388', Case_Fatality_Ratio='1.2891883973044242')]
# [CovidData(Combined_Key='Vinnytsia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='3043', Deaths='63', Recovered='2303', Active='677.0', Incidence_Rate='195.01484881382527', Case_Fatality_Ratio='2.0703253368386463')]
# [CovidData(Combined_Key='Volyn Oblast, Ukraine', Country_Region='Ukraine', Confirmed='4423', Deaths='95', Recovered='3260', Active='1068.0', Incidence_Rate='427.2067843103165', Case_Fatality_Ratio='2.147863441103324')]
# [CovidData(Combined_Key='Zakarpattia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='5946', Deaths='226', Recovered='2563', Active='3157.0', Incidence_Rate='473.1055488454029', Case_Fatality_Ratio='3.800874537504205')]
# [CovidData(Combined_Key='Zaporizhia Oblast, Ukraine', Country_Region='Ukraine', Confirmed='971', Deaths='22', Recovered='680', Active='269.0', Incidence_Rate='56.92223636973308', Case_Fatality_Ratio='2.265705458290422')]
# [CovidData(Combined_Key='Zhytomyr Oblast, Ukraine', Country_Region='Ukraine', Confirmed='2215', Deaths='48', Recovered='1574', Active='593.0', Incidence_Rate='181.52865981037425', Case_Fatality_Ratio='2.1670428893905203')]
# [CovidData(Combined_Key='United Arab Emirates', Country_Region='United Arab Emirates', Confirmed='63212', Deaths='358', Recovered='57193', Active='5661.0', Incidence_Rate='639.124807894524', Case_Fatality_Ratio='0.5663481617414415')]
# [CovidData(Combined_Key='Anguilla, United Kingdom', Country_Region='United Kingdom', Confirmed='3', Deaths='0', Recovered='3', Active='0.0', Incidence_Rate='19.99733368884149', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Bermuda, United Kingdom', Country_Region='United Kingdom', Confirmed='159', Deaths='9', Recovered='145', Active='5.0', Incidence_Rate='255.32734893131854', Case_Fatality_Ratio='5.660377358490566')]
# [CovidData(Combined_Key='British Virgin Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='9', Deaths='1', Recovered='7', Active='1.0', Incidence_Rate='29.76485762476436', Case_Fatality_Ratio='11.111111111111107')]
# [CovidData(Combined_Key='Cayman Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='203', Deaths='1', Recovered='202', Active='0.0', Incidence_Rate='308.8861838101035', Case_Fatality_Ratio='0.4926108374384237')]
# [CovidData(Combined_Key='Channel Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='603', Deaths='47', Recovered='545', Active='11.0', Incidence_Rate='353.66776344729294', Case_Fatality_Ratio='7.794361525704807')]
# [CovidData(Combined_Key='England, United Kingdom', Country_Region='United Kingdom', Confirmed='270971', Deaths='42072', Recovered='0', Active='228899.0', Incidence_Rate='484.07387293398034', Case_Fatality_Ratio='15.526384742278696')]
# [CovidData(Combined_Key='Falkland Islands (Malvinas), United Kingdom', Country_Region='United Kingdom', Confirmed='13', Deaths='0', Recovered='13', Active='0.0', Incidence_Rate='373.2414585127763', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Gibraltar, United Kingdom', Country_Region='United Kingdom', Confirmed='203', Deaths='0', Recovered='187', Active='16.0', Incidence_Rate='602.5348015790568', Case_Fatality_Ratio='0.0')]
# [CovidData(Combined_Key='Isle of Man, United Kingdom', Country_Region='United Kingdom', Confirmed='336', Deaths='24', Recovered='312', Active='0.0', Incidence_Rate='395.14535704205474', Case_Fatality_Ratio='7.142857142857142')]
# [CovidData(Combined_Key='Montserrat, United Kingdom', Country_Region='United Kingdom', Confirmed='13', Deaths='1', Recovered='12', Active='0.0', Incidence_Rate='260.05201040208044', Case_Fatality_Ratio='7.6923076923076925')]
# [CovidData(Combined_Key='Northern Ireland, United Kingdom', Country_Region='United Kingdom', Confirmed='6217', Deaths='557', Recovered='0', Active='5660.0', Incidence_Rate='330.41028911564626', Case_Fatality_Ratio='8.959305131092169')]
# [CovidData(Combined_Key='Scotland, United Kingdom', Country_Region='United Kingdom', Confirmed='19126', Deaths='2491', Recovered='0', Active='16635.0', Incidence_Rate='350.08145260190724', Case_Fatality_Ratio='13.024155599707205')]
# [CovidData(Combined_Key='Turks and Caicos Islands, United Kingdom', Country_Region='United Kingdom', Confirmed='241', Deaths='2', Recovered='46', Active='193.0', Incidence_Rate='622.4495066893951', Case_Fatality_Ratio='0.8298755186721992')]
# [CovidData(Combined_Key='Unknown, United Kingdom', Country_Region='United Kingdom', Confirmed='0', Deaths='0', Recovered='0', Active='0.0', Incidence_Rate='-99.0', Case_Fatality_Ratio='-99.0')]
# [CovidData(Combined_Key='Wales, United Kingdom', Country_Region='United Kingdom', Confirmed='17484', Deaths='1586', Recovered='0', Active='15898.0', Incidence_Rate='557.0636589562225', Case_Fatality_Ratio='9.071150766415009')]
# [CovidData(Combined_Key='Uruguay', Country_Region='Uruguay', Confirmed='1393', Deaths='37', Recovered='1163', Active='193.0', Incidence_Rate='40.101021179845155', Case_Fatality_Ratio='2.656137832017229')]
# [CovidData(Combined_Key='Uzbekistan', Country_Region='Uzbekistan', Confirmed='32654', Deaths='211', Recovered='25659', Active='6784.0', Incidence_Rate='97.56433071493583', Case_Fatality_Ratio='0.6461689226434739')]
# [CovidData(Combined_Key='Venezuela', Country_Region='Venezuela', Confirmed='29088', Deaths='247', Recovered='21042', Active='7799.0', Incidence_Rate='102.29307324184748', Case_Fatality_Ratio='0.8491474147414741')]
# [CovidData(Combined_Key='Vietnam', Country_Region='Vietnam', Confirmed='883', Deaths='18', Recovered='409', Active='456.0', Incidence_Rate='0.9071428541342133', Case_Fatality_Ratio='2.0385050962627407')]
# [CovidData(Combined_Key='West Bank and Gaza', Country_Region='West Bank and Gaza', Confirmed='15184', Deaths='105', Recovered='8369', Active='6710.0', Incidence_Rate='297.6428505340478', Case_Fatality_Ratio='0.6915173867228662')]
# [CovidData(Combined_Key='Western Sahara', Country_Region='Western Sahara', Confirmed='10', Deaths='1', Recovered='8', Active='1.0', Incidence_Rate='1.674116485025028', Case_Fatality_Ratio='10.0')]
# [CovidData(Combined_Key='Yemen', Country_Region='Yemen', Confirmed='1841', Deaths='528', Recovered='937', Active='376.0', Incidence_Rate='6.172473597504027', Case_Fatality_Ratio='28.680065181966324')]
# [CovidData(Combined_Key='Zambia', Country_Region='Zambia', Confirmed='8501', Deaths='246', Recovered='7233', Active='1022.0', Incidence_Rate='46.24140745332506', Case_Fatality_Ratio='2.8937772026820374')]
# [CovidData(Combined_Key='Zimbabwe', Country_Region='Zimbabwe', Confirmed='4893', Deaths='122', Recovered='1620', Active='3151.0', Incidence_Rate='32.92083719445033', Case_Fatality_Ratio='2.493357858164725')]

# %% [markdown]
# #### Convert numeric data to floats.
# 1. use a loop to convert only the numeric data (i.e. numbers represented as strings) to float values. You'll have to come up with a way to skip the non-numeric data.
#
# 2. If you used namedtuples this is a little trickier since namedtuples are immutable (can't be changed).
#
# Hint: you need to use a placeholder data type that you can convert the values. After conversion put everything back into a namedtuple.

# %% [markdown]
# ##### Convert the appropriate elements of ```data``` to floats.

# %%
# convert all numerical data to floats.
clean_data = []

for row in data :
    new_row = []
    
    for i, col in enumerate(row):      #loop every item in that row. Row = row, i = index, col is the actual text
         
        if i < 2 :                   #do not need to check for the first 2 columns: last, first, sex
            new_row.append(col)
        else:
            new_row.append(float(col))     #convert to float
            
    clean_data.append(new_row)           #add new row to Clean data array
   
for i in range(6):  
    print(clean_data[i])
# Out:
# ['Afghanistan', 'Afghanistan', 37345.0, 1354.0, 26694.0, 9297.0, 95.93267794278722, 3.6256526978176464]
# ['Albania', 'Albania', 6817.0, 208.0, 3552.0, 3057.0, 236.882340676906, 3.0511955405603635]
# ['Algeria', 'Algeria', 36699.0, 1333.0, 25627.0, 9739.0, 83.69014164611774, 3.6322515599880094]
# ['Andorra', 'Andorra', 977.0, 53.0, 855.0, 69.0, 1264.4793891153822, 5.424769703172978]
# ['Angola', 'Angola', 1762.0, 80.0, 577.0, 1105.0, 5.361119796138704, 4.540295119182747]
# ['Antigua and Barbuda', 'Antigua and Barbuda', 92.0, 3.0, 76.0, 13.0, 93.94657299240258, 3.260869565217391]

# %% [markdown]
# ##### an alternative approach to convert the elements of ```data``` to floats.

# %%
# alternative approach

clean_data = []

for row in data :
    new_row  =  [col if i < 2 else  float(col)  for i,col in enumerate(row) ]
    clean_data.append(new_row )

for i in range(6):  
    print( clean_data[i])
# Out:
# ['Afghanistan', 'Afghanistan', 37345.0, 1354.0, 26694.0, 9297.0, 95.93267794278722, 3.6256526978176464]
# ['Albania', 'Albania', 6817.0, 208.0, 3552.0, 3057.0, 236.882340676906, 3.0511955405603635]
# ['Algeria', 'Algeria', 36699.0, 1333.0, 25627.0, 9739.0, 83.69014164611774, 3.6322515599880094]
# ['Andorra', 'Andorra', 977.0, 53.0, 855.0, 69.0, 1264.4793891153822, 5.424769703172978]
# ['Angola', 'Angola', 1762.0, 80.0, 577.0, 1105.0, 5.361119796138704, 4.540295119182747]
# ['Antigua and Barbuda', 'Antigua and Barbuda', 92.0, 3.0, 76.0, 13.0, 93.94657299240258, 3.260869565217391]

# %% [markdown]
# ##### Convert the appropriate elements of data_named to floats.
# Note that this is a touch more complicated since namedtuples are immutable and elements cannot be changed.
#
# So the approach is to create a dictionary for each row and add each element of the namedtuples to the dictionary, converting the type when necessary. We end up with a list of dictionaries with all the same information, but all numerical values are now floats.

# %%
#dictionary for each row 
#create an array of dictionaries
data_dict = {}
for j,x in enumerate(data_named[0:]) :                      #get 1 row
    row_dict = {}
    for i,col in enumerate(((covid_data(*x)[0:]))):              #add each element of the namedtuples to the dictionary
          if i > 1 and not col == None:                         #converting all numerice types to float
            row_dict[covid_data._fields[i]] = float(col)      
                                                            
          else:
            row_dict[covid_data._fields[i]] = (col)            #Add non numeric columns without converting

    data_dict[j] = row_dict  
                                                           

for i,item in enumerate(data_dict.items()):
    if i < 3:
        print(item)
# Out:
# (0, {'Combined_Key': 'Afghanistan', 'Country_Region': 'Afghanistan', 'Confirmed': 37345.0, 'Deaths': 1354.0, 'Recovered': 26694.0, 'Active': 9297.0, 'Incidence_Rate': 95.93267794278722, 'Case_Fatality_Ratio': 3.6256526978176464})
# (1, {'Combined_Key': 'Albania', 'Country_Region': 'Albania', 'Confirmed': 6817.0, 'Deaths': 208.0, 'Recovered': 3552.0, 'Active': 3057.0, 'Incidence_Rate': 236.882340676906, 'Case_Fatality_Ratio': 3.0511955405603635})
# (2, {'Combined_Key': 'Algeria', 'Country_Region': 'Algeria', 'Confirmed': 36699.0, 'Deaths': 1333.0, 'Recovered': 25627.0, 'Active': 9739.0, 'Incidence_Rate': 83.69014164611774, 'Case_Fatality_Ratio': 3.6322515599880094})

# %% [markdown]
# ##### an alternative approach to convert the appropriate elements of ```data_named``` to floats.

# %%
def convert_namedtuple(tuple_): 

    x=[float(i) if isinstance(i, int) or isinstance(i, float) else i for a,i in enumerate(tuple_) ]
   
    return tuple(x)

# %%
 

for i , row in enumerate (data_named):
                       
    #x = covid_data._make(convert_namedtuple(row))   #convert converted tuple to named tuple
    #data_named[i].update(tuple(tuple_row))           #update tuple array with converted named tuple
    data_named[i] = covid_data._make(convert_namedtuple(row))

# %%
#import collections as col

 
for x in data_named[:] : 
    for i in range(len_data_named ): 
        tuple_row = []
        tuple_row.append(x.Combined_Key)   
        tuple_row.append(x.Country_Region)   
        tuple_row.append(float(x.Confirmed ))  
        tuple_row.append(float(x.Deaths))  
        tuple_row.append(float(x.Recovered))  
        tuple_row.append(float(x.Active ))  
        tuple_row.append(float(x.Incidence_Rate) )  
        tuple_row.append(float(x.Case_Fatality_Ratio)  ) 
     
    data_named[i] = tuple(tuple_row)

# %%
new_data_named[0:3]

# %%
covid_data._fields

# %%
# check the result -

#dictionary of dictionaries
print (f"How many Keys / cols are in covid_data dictionaries? { len(data_dict.keys()) }")
print (f"How many items/rows are in 1 key of covid_data dictionaries? {len(data_dict )}")
    


#get row count 
print(f"How many rows are in this tuples list? {len(new_data_named)}")
 
#get column count for 1 row -  {len(header)}") 
print(f"How many columns are in this tuple row? {len(covid_data(*x))}")

# %% [markdown]
# ### Part 4: Calculate the average number of active cases and average number of deaths.
#
# 1. Compute the average for active cases
# 2. Compute the average number of deaths.
# 3. Compute the average total number of cases.
#
# Hint: Review the data dictionary to determine the correct information to use.
#
# Hint: Don't over think this. Try to find the simplest approach.

# %% [markdown]
# #### Find the average using the standard ```data```

# %%
# Create a list for active case counts and deaths
active_cases = []
deaths = []
recovered = []
confirmed = []

for row in clean_data :
    active_cases.append(row[5])
    deaths.append(  row[3])   
    recovered.append( row[4])
    confirmed.append(row[2])

# %%
def get_avg(lst):
    return  round(sum(lst) / len(lst),2)

# %%
active_avg  = get_avg(active_cases)
print(" average for active cases =", active_avg  )

# %%
death_avg = get_avg(deaths)
print(" average for active cases =", death_avg)

# %%
#per data dictionary , Active: Active cases = total cases - total recovered - total deaths.
#so, total cases = Active + Recovered + Deaths
recov_avg = get_avg(recovered)
print(" average for recovered cases =", recov_avg)

# %%
total_cases = sum(active_cases) + sum(deaths) + sum(recovered)

# %%
# Calculate the average number of cases per country
 
avg_cases_country = {}

for x in data_named[0:] :
     avg_cases_country[x.Country_Region] =  (float(x.Active) + float(x.Deaths)  + float(x.Recovered))/total_cases

# %%
# Calculate the average number of cases per country
 
for i,item in enumerate(avg_cases_country.items()):
    if i < 3:
        print(item)

# %% [markdown]
# #### Find the average using the namedtuple ```data_named```

# %%
def find_avg(tuple_):
    avg_Active = round(sum(float(x.Active)  for x in tuple_)/len(tuple_),2) 
    avg_Deaths = round(sum(float(x.Deaths)  for x in tuple_)/len(tuple_),2)
    return avg_Active,avg_Deaths

# %%
find_avg( data_named)
print(" average for active cases =", find_avg( data_named)[0]) 
print(" average for death cases =", find_avg( data_named)[1])

# %%
# Create a list for active case counts and deaths
# Note: Don't forget to convert to floats
 

# namedtuple approach
active   = [float(x.Active)  for x in data_named]
deaths  = [float(x.Deaths)  for x in data_named]


active_avg  = get_avg(active)
print(" average for active cases =", active_avg )

# %%
death_avg  = get_avg(deaths)
print(" average for active cases =", death_avg)

# %% [markdown]
# **Compute the Average total number of cases**

# %% [markdown]
# #### What information do we need to get this result?
#  total death + total active cases

# %%
 #Calculate the average total number of cases per country
avg_total_cases = active_avg  + death_avg  + recov_avg

avg_total_cases

# %% [markdown]
# ### Part 5: Create an object ```countries``` that contains all the country names in the data set. Each country should only be listed once.
#
# 1. Create a list (or other python data type) of unique country names.
# 2. Print total number of unique countries represented in the data set.
# 3. Print the first 5 names and the last 5 names - Print your results neatly and annotate. Your results should be in alphabetical order.

# %%
header

# %%
countries = []
for row in data: 
    for i, cell in enumerate(row):
        if i == 1 and cell not in countries:
            countries.append(cell)

# %%
countries [0:3]

# %%
# Print total number of unique countries represented in the data set.
 
len(countries)

# %%
# print the first 5.
countries[:5]

# %%
# print the last 5
countries[-5:]

# %% [markdown]
# ### Part 6: Calculate the average number of confirmed cases for the first 5 countries and the last 5 countries.
#
# 1. Determine the average number of confirmed cases for the first 5 countries.
# 2. Determine the average number of confirmed cases for the last 5 countries.
#
#
# Note: Print your results neatly and properly annotated.
#
# Hint: Think carefully about the easiest way to count the number of confirmed cases!

# %%
#Determine the average number of confirmed cases for the first 5 countries.
x = sum(float(data[i][2]) for i in range(5) )

# %%
avg_confirmed_first5 = x /sum(confirmed)            
print(f" The average number of confirmed cases first 5 countries: {avg_confirmed_first5}")

# %%
#Determine the average number of confirmed cases for the first 5 countries.
y = sum(float(data[i][2]) for i in range(len(data) -5))

# %%
avg_confirmed_last5 = y /sum(confirmed)            
print(f" The average number of confirmed cases last 5 countries: {avg_confirmed_last5}")

# %% [markdown]
# ### Problem 7: Create a dictionary of confirmed cases in the EU.
#
# The keys in the dictionary are the countries in Europe and the values will be the total number of confirmed cases.
#
# **Expected output**: `{'Austria': 22439, 'Belgium': 75647, ...  }` (*required*)
#
# **Bonus**: use `.defaultdict()` to simplify your code. (*optional*)
#
# See: [Python Doc - defaultdict](https://docs.python.org/3/library/collections.html?highlight=defaultdict#collections.defaultdict) or [Stackoverflow - defaultdict](https://stackoverflow.com/questions/5900578/how-does-collections-defaultdict-work)

# %%
# a list of EU countries
eu = ['Austria',
'Belgium',
'Bulgaria',
'Croatia',
'Cyprus',
'Czechia',
'Denmark',
'Estonia',
'Finland',
'France',
'Germany',
'Greece',
'Hungary',
'Ireland',
'Italy',
'Latvia',
'Lithuania',
'Luxembourg',
'Malta',
'Netherlands',
'Poland',
'Portugal',
'Romania',
'Slovakia',
'Slovenia',
'Spain',
'Sweden']

# %%
header

# %%
#The keys in the dictionary are the countries in Europe and the values will be the total number of confirmed cases.
is_eu = {}
for row in data: 
    for i, cell in enumerate(row):
        if i == 1 and cell  in eu:
            is_eu[cell] = row[2]

for i,item in enumerate(is_eu.items()):
    if i < 3:
        print ( item )  
        
type(is_eu)

# %% [markdown]
# A very efficient way to retrieve anything is to combine list or dictionary comprehensions with slicing. If you don't need to order the items (you just want n random pairs), you can use a dictionary comprehension like this:
#
# # Python 2
# first2pairs = {k: mydict[k] for k in mydict.keys()[:2]}
# # Python 3
# first2pairs = {k: mydict[k] for k in list(mydict)[:2]}
# Generally a comprehension like this is always faster to run than the equivalent "for x in y" loop. Also, by using .keys() to make a list of the dictionary keys and slicing that list you avoid 'touching' any unnecessary keys when you build the new dictionary.
#
# If you don't need the keys (only the values) you can use a list comprehension:
#
# first2vals = [v for v in mydict.values()[:2]]
# If you need the values sorted based on their keys, it's not much more trouble:
#
# first2vals = [mydict[k] for k in sorted(mydict.keys())[:2]]
# or if you need the keys as well:
#
# first2pairs = {k: mydict[k] for k in sorted(mydict.keys())[:2]}

# %%
is_eu_tup = {}

# if you used a named tuple - answer here

for x in data_named[0:] :
     if x.Country_Region in eu:
         is_eu_tup[x.Country_Region] = float(x.Confirmed)

# %%
for i,item in enumerate(is_eu_tup.items()):
    if i < 3:
        print ( item )  
        
type(is_eu_tup)

# %%
#try with a defaultdict
#defaultdict, on the other hand, will insert a key into the dictionary if it isn't there yet
#Key Error 
from collections import defaultdict
 

#  Check value of a key 'Case_Fatality_Ratio' in my dictionary  covid_data_dict
#check value that is not there
is_eu_tup['Case_Fatality '] 
#Got a KeyError

# %% [raw]
# try:
#     is_eu_tup['Case_Fatality ']
# except KeyError:
#     print("Exception - Key is Not present in the dictionary")

# %%
#set default value for keys not found
is_eu_tup = defaultdict(lambda: "Key is Not present in the dictionary")

# %%
is_eu_tup['Case_Fatality ']

# %% [markdown]
# ### Problem 8: Compare the Case Fatality Rate in the EU to that in the US and North America.
#
# 1. Determine the CFR in the EU
# 2. Determine the CFR in the US
# 3. Determine the CFR in North America
#
# Note: The Case Fatality Rate is a feature in this data set. You are not to use that feature. You should compute the CFR from the other available features. Use the existing CFR column as a check.

# %% [markdown]
# Per data dictionary
# Case_Fatality_Ratio (%): Case-Fatality Ratio (%) = Number recorded deaths / Number cases.

# %%
#create filter
is_eu = prod_df['Country_Region'].isin(eu) 

#Create a dictionary of confirmed cases in the EU.
prod_df[is_eu]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_eu_cfr = pd.DataFrame(prod_df[is_eu][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_eu_cfr['Calculated Case Fatality Rate'] = df_eu_cfr['Deaths']/df_eu_cfr['Confirmed'] * 100
 
df_eu_cfr

# %%
# countries in North America
na = ['Antigua and Barbuda',
'Bahamas',
'Barbados',
'Belize',
'Canada',
'Costa Rica',
'Cuba',
'Dominica',
'Dominican Republic',
'El Salvador',
'Grenada',
'Guatemala',
'Haiti',
'Honduras',
'Jamaica',
'Mexico',
'Nicaragua',
'Panama',
'Saint Kitts and Nevis',
'Saint Lucia',
'Saint Vincent and the Grenadines',
'Trinidad and Tobago',
'US']

# %%
#create filter
is_na = prod_df['Country_Region'].isin(na) 

#Create a dictionary of confirmed cases in the EU.
prod_df[is_na]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_na_cfr = pd.DataFrame(prod_df[is_na][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_na_cfr['Calculated Case Fatality Rate'] = df_na_cfr['Deaths']/df_na_cfr['Confirmed']  * 100
 
df_na_cfr

# %%
#create filter
is_us = prod_df['Country_Region'] == 'US'

#Create a dictionary of confirmed cases in the EU.
prod_df[is_us]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_us_cfr = pd.DataFrame(prod_df[is_us][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_us_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed'] * 100
 
df_us_cfr

# %%
# write a function

def create_df_calc_cfr(arg_region,mylist):
    if (arg_region == 'na') | (arg_region == 'eu'):
        is_in =  prod_df['Country_Region'].isin(mylist)
        prod_df[is_in]['Country_Region']
        df_isin_cfr = pd.DataFrame(prod_df[is_in][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )
        df_isin_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed']  * 100
    
    else:
        is_in =  prod_df['Country_Region'] == arg_region
        prod_df[is_in]['Country_Region']
        df_isin_cfr = pd.DataFrame(prod_df[is_us][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )
        df_isin_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed']  * 100
    return df_isin_cfr

# %%
create_df_calc_cfr('US',[])

# %%
create_df_calc_cfr('na',na)

# %% [markdown]
# ### Bonus 1: Craft a problem statement about this data that interests you, and then answer it!

# %%
#The highest number of Confirmed cases held by a country: 
largest = max(float(data[i][2]) for i in range(len(data) ))

# %%
print(f" The highest number of Confirmed cases held by a country: {largest}")

# %%
#The least number of Confirmed cases held by a country:
smallest = min(float(data[i][2]) for i in range(len(data) ))

# %%
print(f" The least number of Confirmed cases held by a country: {smallest}")

# %% [markdown]
# ### Bonus 2: Repeat the above analysis using Pandas!

# %% [markdown]
# ##### Part 5: Create an object ```countries``` that contains all the country names in the data set. Each country should only be listed once.
#
# 1. Create a list (or other python data type) of unique country names.
# 2. Print total number of unique countries represented in the data set.
# 3. Print the first 5 names and the last 5 names - Print your results neatly and annotate. Your results should be in alphabetical order.

# %%
# Where are countries in the rows
import pandas as pd
prod_df = pd.read_csv(DATA_FILE, sep=',')
 
counrtry_list = prod_df['Country_Region'].sort_values(ascending=False)

# %%
counrtry_list

# %%
# Print total number of unique countries represented in the data set.
 
prod_df['Country_Region'].nunique()

# %%
# print the first 5.
prod_df.head(5)[['Country_Region']]

# %%
# print the last 5
prod_df.tail(5)[['Country_Region']]

# %% [markdown]
# #####  Part 6: Calculate the average number of confirmed cases for the first 5 countries and the last 5 countries.
#
# 1. Determine the average number of confirmed cases for the first 5 countries.
# 2. Determine the average number of confirmed cases for the last 5 countries.
#
#
# Note: Print your results neatly and properly annotated.
#
# Hint: Think carefully about the easiest way to count the number of confirmed cases!

# %%
prod_df['Confirmed'].head().mean()

# %%
#sort biggest to smallest
first5_avg = prod_df['Confirmed'].head(5).sort_values(ascending=False).mean() 

print(f" The average number of confirmed cases for the first 5 countries {first5_avg}")

# %%
last5_avg = prod_df['Confirmed'].tail(5).sort_values(ascending=False).mean() 

print(f" The average number of confirmed cases for the first 5 countries {last5_avg}")

# %%
# write a function
def findavg(df_data):
    last5_avg = prod_df['Confirmed'].tail(5).sort_values(ascending=False).mean() 
    first5_avg = prod_df['Confirmed'].head(5).sort_values(ascending=False).mean()    
    return   last5_avg, first5_avg

findavg(prod_df)
print(f" The average number of confirmed cases for the first 5 countries {findavg(prod_df)[0]}")
print(f" The average number of confirmed cases for the first 5 countries {findavg(prod_df)[1]}")

# %% [markdown]
# #####  Problem 7: Create a dictionary of confirmed cases in the EU.
#
# The keys in the dictionary are the countries in Europe and the values will be the total number of confirmed cases.
#
# **Expected output**: `{'Austria': 22439, 'Belgium': 75647, ...  }` (*required*)
#
# **Bonus**: use `.defaultdict()` to simplify your code. (*optional*)
#
# See: [Python Doc - defaultdict](https://docs.python.org/3/library/collections.html?highlight=defaultdict#collections.defaultdict) or [Stackoverflow - defaultdict](https://stackoverflow.com/questions/5900578/how-does-collections-defaultdict-work)

# %%
# a list of EU countries
eu = ['Austria',
'Belgium',
'Bulgaria',
'Croatia',
'Cyprus',
'Czechia',
'Denmark',
'Estonia',
'Finland',
'France',
'Germany',
'Greece',
'Hungary',
'Ireland',
'Italy',
'Latvia',
'Lithuania',
'Luxembourg',
'Malta',
'Netherlands',
'Poland',
'Portugal',
'Romania',
'Slovakia',
'Slovenia',
'Spain',
'Sweden']

# %%
#create filter
is_eu = prod_df['Country_Region'].isin(eu) 

#Create a dictionary of confirmed cases in the EU.
prod_df[is_eu][['Country_Region','Confirmed']]

# %%
#You can use df. to_dict() in order to convert the DataFrame to a dictionary
df = pd.DataFrame(prod_df[is_eu][['Country_Region','Confirmed']],columns=['Country_Region','Confirmed'] )
df.set_index('Country_Region', inplace=True)
df = df.rename_axis(None)  

my_dictionary = df.to_dict()
my_dictionary.items()

# %%
# if you used a named tuple - answer here
#iterate each element and convert to dictionary

#show named tuple as a dictionary
covid_data_dict = {}

#build the keys
for p in header[:]:                   #add column headers sex,age,sibsp,pclass,far,survival
    covid_data_dict[p] = [] 
    
for row in array_of_tuples[: ]:
      for i,cell in enumerate(row): 
            #print(row._asdict())        #add the entire as a dict 
           # print (i)                    #append cells to existing dictionary keyes
           # print (cell)
            covid_data_dict[header[i]].append(cell)

#print(covid_data_dict.items())

# %%
#try with a defaultdict
#defaultdict, on the other hand, will insert a key into the dictionary if it isn't there yet
#Key Error 
from collections import defaultdict
 

#  Check value of a key 'Case_Fatality_Ratio' in my dictionary  covid_data_dict
covid_data_dict['Case_Fatality_Ratio'][0:5]

# %%
#check value that is not there
covid_data_dict['Case_Fatality '] 
#Got a KeyError

# %% [raw]
# try:
#     covid_data_dict['Case_Fatality ']
# except KeyError:
#     print("Exception - Key is Not present in the dictionary")

# %%
#set default value for keys not found
covid_data_dict = defaultdict(lambda: "Key is Not present in the dictionary")

# %%
covid_data_dict['Case_Fatality ']

# %% [markdown]
# #####  Problem 8: Compare the Case Fatality Rate in the EU to that in the US and North America.
#
# 1. Determine the CFR in the EU
# 2. Determine the CFR in the US
# 3. Determine the CFR in North America
#
# Note: The Case Fatality Rate is a feature in this data set. You are not to use that feature. You should compute the CFR from the other available features. Use the existing CFR column as a check.

# %% [markdown]
# Per data dictionary
# Case_Fatality_Ratio (%): Case-Fatality Ratio (%) = Number recorded deaths / Number cases.

# %%
#create filter
is_eu = prod_df['Country_Region'].isin(eu) 

#Create a dictionary of confirmed cases in the EU.
prod_df[is_eu]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_eu_cfr = pd.DataFrame(prod_df[is_eu][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_eu_cfr['Calculated Case Fatality Rate'] = df_eu_cfr['Deaths']/df_eu_cfr['Confirmed'] * 100
 
df_eu_cfr

# %%
# countries in North America
na = ['Antigua and Barbuda',
'Bahamas',
'Barbados',
'Belize',
'Canada',
'Costa Rica',
'Cuba',
'Dominica',
'Dominican Republic',
'El Salvador',
'Grenada',
'Guatemala',
'Haiti',
'Honduras',
'Jamaica',
'Mexico',
'Nicaragua',
'Panama',
'Saint Kitts and Nevis',
'Saint Lucia',
'Saint Vincent and the Grenadines',
'Trinidad and Tobago',
'US']

# %%
#create filter
is_na = prod_df['Country_Region'].isin(na) 

#Create a dictionary of confirmed cases in the EU.
prod_df[is_na]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_na_cfr = pd.DataFrame(prod_df[is_na][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_na_cfr['Calculated Case Fatality Rate'] = df_na_cfr['Deaths']/df_na_cfr['Confirmed']  * 100
 
df_na_cfr

# %%
#create filter
is_us = prod_df['Country_Region'] == 'US'

#Create a dictionary of confirmed cases in the EU.
prod_df[is_us]['Country_Region']

#cfr : total deaths/total confirmed * 100
df_us_cfr = pd.DataFrame(prod_df[is_us][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )

df_us_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed'] * 100
 
df_us_cfr

# %%
# write a function

def create_df_calc_cfr(arg_region,mylist):
    if (arg_region == 'na') | (arg_region == 'eu'):
        is_in =  prod_df['Country_Region'].isin(mylist)
        prod_df[is_in]['Country_Region']
        df_isin_cfr = pd.DataFrame(prod_df[is_in][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )
        df_isin_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed']  * 100
    
    else:
        is_in =  prod_df['Country_Region'] == arg_region
        prod_df[is_in]['Country_Region']
        df_isin_cfr = pd.DataFrame(prod_df[is_us][['Country_Region','Confirmed','Deaths','Case_Fatality_Ratio']]  )
        df_isin_cfr['Calculated Case Fatality Rate'] = df_us_cfr['Deaths']/df_us_cfr['Confirmed']  * 100
    return df_isin_cfr

# %%
create_df_calc_cfr('US',[])

# %%
create_df_calc_cfr('na',na)
